# %% [markdown]
# # Comparison of Smoothed Day of the Year Averages

# %% [markdown]
# Fourier series smoothing was used to create day of the year average values for "other weather" parameters from each of the available data sets and time periods.

# %% [markdown]
# The available data sets and parameters are enumerated below.
#
# - PRISM
#     - Maximum daily air temperature
#     - Average daily air temperature, provided as the average between the maximum and the minimum
#     - Minimum daily air temperature
#     - Relative humidity, calculated from dew point temperatuer and vapor pressure deficit
# - CMIP5, LOCA downscaling
#     - Maximum daily air temperature
#     - Minimum daily air temperature
# - CMIP5, BCCA downscaling
#     - Maximum daily air temperature
#     - Minimum daily air temperature

# %% [markdown]
# Climate periods:
#
# 1. Data period: 1981-2010
# 2. Projection period 1: 2011-2040
# 3. Projection period 2: 2041-2070
# 4. Projection period 3: 2071-2100

# %%
# %matplotlib inline

# %%
import os
from IPython.display import display, HTML
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
CIN_DIR1 = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
          r'otes\Processed\CMIP5\OtherWeather_1981-2010'
CIN_DIR2 = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
          r'otes\Processed\CMIP5\OtherWeather_2011-2040'
CIN_DIR3 = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
          r'otes\Processed\CMIP5\OtherWeather_2041-2070'
CIN_DIR4 = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
          r'otes\Processed\CMIP5\OtherWeather_2071-2100'

# %%
LDRY_AVE_1 = "OWeath_LOCA_Dry_Smooth_Ave_1981-2010.pickle"
LWET_AVE_1 = "OWeath_LOCA_Wet_Smooth_Ave_1981-2010.pickle"
LDRY_AVE_2 = "OWeath_LOCA_Dry_Smooth_Ave_2011-2040.pickle"
LWET_AVE_2 = "OWeath_LOCA_Wet_Smooth_Ave_2011-2040.pickle"
LDRY_AVE_3 = "OWeath_LOCA_Dry_Smooth_Ave_2041-2070.pickle"
LWET_AVE_3 = "OWeath_LOCA_Wet_Smooth_Ave_2041-2070.pickle"
LDRY_AVE_4 = "OWeath_LOCA_Dry_Smooth_Ave_2071-2100.pickle"
LWET_AVE_4 = "OWeath_LOCA_Wet_Smooth_Ave_2071-2100.pickle"

# %%
BDRY_AVE_1 = "OWeath_BCCA_Dry_Smooth_Ave_1981-2010.pickle"
BWET_AVE_1 = "OWeath_BCCA_Wet_Smooth_Ave_1981-2010.pickle"
BDRY_AVE_2 = "OWeath_BCCA_Dry_Smooth_Ave_2011-2040.pickle"
BWET_AVE_2 = "OWeath_BCCA_Wet_Smooth_Ave_2011-2040.pickle"
BDRY_AVE_3 = "OWeath_BCCA_Dry_Smooth_Ave_2041-2070.pickle"
BWET_AVE_3 = "OWeath_BCCA_Wet_Smooth_Ave_2041-2070.pickle"
BDRY_AVE_4 = "OWeath_BCCA_Dry_Smooth_Ave_2071-2100.pickle"
BWET_AVE_4 = "OWeath_BCCA_Wet_Smooth_Ave_2071-2100.pickle"

# %%
PRIS_IN_DIR = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
              r'otes\Processed\PRISM\Other_Weather'

# %%
PDRY_AVE = "OWeath_Dry_Smooth_Ave_1981-2010.pickle"
PWET_AVE = "OWeath_Wet_Smooth_Ave_1981-2010.pickle"

# %%
OUT_DIR = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
          r'otes\Processed\CMIP5'

# %% [markdown]
# ## Data Period: 1981 - 2010

# %% [markdown]
# This is the only time period that has PRISM data and the downscaled climate model results

# %% [markdown]
# Read in the PRISM files

# %%
inFile = os.path.normpath( os.path.join( PRIS_IN_DIR, PDRY_AVE ) )
PRISM_DAVE = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( PRIS_IN_DIR, PWET_AVE ) )
PRISM_WAVE = pd.read_pickle( inFile )

# %%
display( HTML( PRISM_DAVE.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmean_C</th>
#       <th>Tmin_C</th>
#       <th>DewPtT_C</th>
#       <th>RelHum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>15.978704</td>
#       <td>7.922270</td>
#       <td>-0.133265</td>
#       <td>-1.139739</td>
#       <td>54.513275</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>15.971680</td>
#       <td>7.905140</td>
#       <td>-0.160498</td>
#       <td>-1.166684</td>
#       <td>54.479912</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>15.970143</td>
#       <td>7.893551</td>
#       <td>-0.182139</td>
#       <td>-1.188840</td>
#       <td>54.445438</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>15.974039</td>
#       <td>7.887478</td>
#       <td>-0.198188</td>
#       <td>-1.206242</td>
#       <td>54.409744</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>15.983322</td>
#       <td>7.886875</td>
#       <td>-0.208667</td>
#       <td>-1.218931</td>
#       <td>54.372784</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( PRISM_DAVE.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmean_C</th>
#       <th>Tmin_C</th>
#       <th>DewPtT_C</th>
#       <th>RelHum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>26.841141</td>
#       <td>19.454414</td>
#       <td>12.068676</td>
#       <td>9.198494</td>
#       <td>52.893932</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>6.844926</td>
#       <td>7.477267</td>
#       <td>8.119375</td>
#       <td>7.028995</td>
#       <td>2.690080</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>15.970143</td>
#       <td>7.886875</td>
#       <td>-0.213599</td>
#       <td>-1.230379</td>
#       <td>47.624954</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>20.413465</td>
#       <td>12.350213</td>
#       <td>4.266902</td>
#       <td>2.252036</td>
#       <td>50.542642</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>27.514650</td>
#       <td>19.925280</td>
#       <td>12.345178</td>
#       <td>9.564064</td>
#       <td>53.547113</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>33.555303</td>
#       <td>27.032238</td>
#       <td>20.473666</td>
#       <td>16.774254</td>
#       <td>55.286058</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>35.864403</td>
#       <td>29.244465</td>
#       <td>22.642818</td>
#       <td>17.905766</td>
#       <td>56.422707</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( PRISM_WAVE.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmean_C</th>
#       <th>Tmin_C</th>
#       <th>DewPtT_C</th>
#       <th>RelHum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>12.004342</td>
#       <td>7.542461</td>
#       <td>3.081444</td>
#       <td>2.937763</td>
#       <td>73.832413</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11.968456</td>
#       <td>7.516122</td>
#       <td>3.064638</td>
#       <td>2.908288</td>
#       <td>73.821342</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>11.937980</td>
#       <td>7.494088</td>
#       <td>3.051048</td>
#       <td>2.883328</td>
#       <td>73.812378</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>11.913011</td>
#       <td>7.476401</td>
#       <td>3.040646</td>
#       <td>2.862903</td>
#       <td>73.805328</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>11.893646</td>
#       <td>7.463113</td>
#       <td>3.033433</td>
#       <td>2.847029</td>
#       <td>73.800041</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( PRISM_WAVE.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmean_C</th>
#       <th>Tmin_C</th>
#       <th>DewPtT_C</th>
#       <th>RelHum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>23.780523</td>
#       <td>18.310371</td>
#       <td>12.841170</td>
#       <td>12.341883</td>
#       <td>69.568787</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.486468</td>
#       <td>6.984807</td>
#       <td>6.498842</td>
#       <td>5.803024</td>
#       <td>4.972375</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>11.870030</td>
#       <td>7.449895</td>
#       <td>3.028560</td>
#       <td>2.826864</td>
#       <td>60.713406</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>16.675791</td>
#       <td>11.548933</td>
#       <td>6.375201</td>
#       <td>6.872577</td>
#       <td>66.122482</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>24.400466</td>
#       <td>18.929902</td>
#       <td>13.424630</td>
#       <td>13.177018</td>
#       <td>69.512318</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>31.578730</td>
#       <td>25.533519</td>
#       <td>19.531301</td>
#       <td>18.509674</td>
#       <td>73.809307</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>33.214813</td>
#       <td>27.032644</td>
#       <td>21.034046</td>
#       <td>19.124378</td>
#       <td>77.243042</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Read in the CMIP5, both types of downscaling

# %%
inFile = os.path.normpath( os.path.join( CIN_DIR1, LWET_AVE_1 ))
LDP_Wet_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR1, LDRY_AVE_1 ))
LDP_Dry_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR1, BWET_AVE_1 ))
BDP_Wet_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR1, BDRY_AVE_1 ))
BDP_Dry_AveDF = pd.read_pickle( inFile )

# %%
display( HTML( LDP_Dry_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>16.570238</td>
#       <td>0.372880</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16.565470</td>
#       <td>0.357498</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16.565163</td>
#       <td>0.346580</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16.569292</td>
#       <td>0.340095</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>16.577820</td>
#       <td>0.338032</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDP_Dry_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>17.078909</td>
#       <td>0.728318</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17.070490</td>
#       <td>0.705960</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17.066156</td>
#       <td>0.688124</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>17.065878</td>
#       <td>0.674798</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>17.069639</td>
#       <td>0.665977</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDP_Dry_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>27.170115</td>
#       <td>11.803450</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>6.836432</td>
#       <td>7.787248</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>16.565163</td>
#       <td>0.338032</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>20.565713</td>
#       <td>4.223937</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>27.886139</td>
#       <td>11.927549</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>33.868824</td>
#       <td>19.776016</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>36.205250</td>
#       <td>22.255302</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDP_Dry_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>27.386927</td>
#       <td>12.335677</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>6.719122</td>
#       <td>7.814383</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>17.065878</td>
#       <td>0.661652</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>20.827784</td>
#       <td>4.666264</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>28.111327</td>
#       <td>12.716292</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>33.864450</td>
#       <td>20.349852</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>36.409863</td>
#       <td>22.528202</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDP_Wet_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>13.812982</td>
#       <td>3.844885</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>13.782653</td>
#       <td>3.815413</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>13.756452</td>
#       <td>3.789687</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>13.734377</td>
#       <td>3.767683</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>13.716460</td>
#       <td>3.749375</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDP_Wet_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>14.881110</td>
#       <td>1.804317</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14.876272</td>
#       <td>1.777292</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14.875978</td>
#       <td>1.754862</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14.880168</td>
#       <td>1.736993</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>14.888800</td>
#       <td>1.723664</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDP_Wet_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>25.077061</td>
#       <td>13.989080</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.262332</td>
#       <td>6.687236</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>13.686662</td>
#       <td>3.712509</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>17.853463</td>
#       <td>7.296522</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>26.361490</td>
#       <td>14.989588</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>32.219054</td>
#       <td>20.741590</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>34.087112</td>
#       <td>22.205671</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDP_Wet_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>25.973392</td>
#       <td>12.686250</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.124615</td>
#       <td>7.141830</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>14.875978</td>
#       <td>1.710497</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>19.019008</td>
#       <td>5.716646</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>26.943988</td>
#       <td>13.407351</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>32.879882</td>
#       <td>19.880430</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>35.271778</td>
#       <td>21.837904</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Plot the wet and dry periods

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_DAVE.plot( y="Tmax_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Dry_AveDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
BDP_Dry_AveDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                    label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Averages, 1981-2011", fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_DAVE.plot( y="Tmax_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Dry_AveDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_WAVE.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
BDP_Wet_AveDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                    label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Averages, 1981-2011", fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_WAVE.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_DAVE.plot( y="Tmin_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Dry_AveDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
BDP_Dry_AveDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                    label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Averages, 1981-2011", fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_DAVE.plot( y="Tmin_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Dry_AveDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_WAVE.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
BDP_Wet_AveDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                    label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Averages, 1981-2011", fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_WAVE.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ## Projection Period 1: 2011-2040

# %% [markdown]
# Read in the CMIP5 values - these are all that are available for a projection period

# %%
CDateRange = '2011-2040'

# %%
inFile = os.path.normpath( os.path.join( CIN_DIR2, LWET_AVE_2 ))
LDPr1_Wet_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR2, LDRY_AVE_2 ))
LDPr1_Dry_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR2, BWET_AVE_2 ))
BDPr1_Wet_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR2, BDRY_AVE_2 ))
BDPr1_Dry_AveDF = pd.read_pickle( inFile )

# %%
display( HTML( LDPr1_Dry_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>17.853806</td>
#       <td>1.366040</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17.849367</td>
#       <td>1.346810</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17.848883</td>
#       <td>1.331775</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>17.852316</td>
#       <td>1.320924</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>17.859625</td>
#       <td>1.314240</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr1_Dry_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>18.139635</td>
#       <td>1.432054</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>18.132080</td>
#       <td>1.408449</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>18.128380</td>
#       <td>1.389318</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>18.128485</td>
#       <td>1.374642</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>18.132351</td>
#       <td>1.364421</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr1_Dry_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>28.400364</td>
#       <td>12.905879</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>6.899059</td>
#       <td>7.941716</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>17.848883</td>
#       <td>1.311707</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>21.571286</td>
#       <td>5.083500</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>29.188097</td>
#       <td>13.057183</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>35.192928</td>
#       <td>21.047397</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>37.410213</td>
#       <td>23.532194</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr1_Dry_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>28.405603</td>
#       <td>13.178751</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>6.749218</td>
#       <td>7.916932</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>18.128380</td>
#       <td>1.357239</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>21.714034</td>
#       <td>5.364711</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>29.187214</td>
#       <td>13.673397</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>34.921640</td>
#       <td>21.287514</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>37.439671</td>
#       <td>23.419367</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr1_Wet_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>14.866104</td>
#       <td>4.909068</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14.842277</td>
#       <td>4.885467</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14.822634</td>
#       <td>4.865441</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14.807151</td>
#       <td>4.848941</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>14.795803</td>
#       <td>4.835924</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr1_Wet_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>15.956147</td>
#       <td>2.543417</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>15.951400</td>
#       <td>2.515842</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>15.950872</td>
#       <td>2.492582</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>15.954510</td>
#       <td>2.473602</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>15.962235</td>
#       <td>2.458852</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr1_Wet_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>26.191788</td>
#       <td>15.033403</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.304173</td>
#       <td>6.733645</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>14.785515</td>
#       <td>4.817307</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>18.897353</td>
#       <td>8.213639</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>27.500730</td>
#       <td>16.016199</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>33.452292</td>
#       <td>21.873902</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>35.102264</td>
#       <td>23.308796</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr1_Wet_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>26.946604</td>
#       <td>13.475679</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.143237</td>
#       <td>7.245197</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>15.950872</td>
#       <td>2.439614</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>19.869230</td>
#       <td>6.276669</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>27.947262</td>
#       <td>14.330077</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>33.851123</td>
#       <td>20.745048</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>36.280296</td>
#       <td>22.702978</td>
#     </tr>
#   </tbody>
# </table>

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr1_Dry_AveDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr1_Dry_AveDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr1_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr1_Wet_AveDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr1_Dry_AveDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr1_Dry_AveDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr1_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr1_Wet_AveDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ## Projection Period 2: 2041-2070

# %% [markdown]
# Read in the CMIP5 values - these are all that are available for a projection period

# %%
CDateRange = '2041-2070'

# %%
inFile = os.path.normpath( os.path.join( CIN_DIR3, LWET_AVE_3 ))
LDPr2_Wet_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR3, LDRY_AVE_3 ))
LDPr2_Dry_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR3, BWET_AVE_3 ))
BDPr2_Wet_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR3, BDRY_AVE_3 ))
BDPr2_Dry_AveDF = pd.read_pickle( inFile )

# %%
display( HTML( LDPr2_Dry_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>18.870255</td>
#       <td>2.342074</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>18.863281</td>
#       <td>2.320945</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>18.860294</td>
#       <td>2.304037</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>18.861248</td>
#       <td>2.291331</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>18.866110</td>
#       <td>2.282810</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr2_Dry_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>19.115013</td>
#       <td>2.060736</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>19.108086</td>
#       <td>2.037747</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>19.104979</td>
#       <td>2.019321</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>19.105639</td>
#       <td>2.005440</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>19.110027</td>
#       <td>1.996081</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr2_Dry_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>29.592091</td>
#       <td>14.104395</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.008527</td>
#       <td>8.087651</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>18.860294</td>
#       <td>2.278232</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>22.676421</td>
#       <td>6.108670</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>30.439563</td>
#       <td>14.342938</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>36.522024</td>
#       <td>22.440612</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>38.671734</td>
#       <td>24.775768</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr2_Dry_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>29.361774</td>
#       <td>13.979512</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>6.739607</td>
#       <td>8.017699</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>19.104979</td>
#       <td>1.990833</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>22.689279</td>
#       <td>6.048367</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>30.151894</td>
#       <td>14.523139</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>35.911932</td>
#       <td>22.229060</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>38.316242</td>
#       <td>24.263357</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr2_Wet_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>15.807350</td>
#       <td>5.839122</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>15.778823</td>
#       <td>5.807397</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>15.754849</td>
#       <td>5.779519</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>15.735424</td>
#       <td>5.755452</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>15.720540</td>
#       <td>5.735179</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr2_Wet_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>16.862665</td>
#       <td>3.111766</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16.857315</td>
#       <td>3.084255</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16.856361</td>
#       <td>3.061252</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16.859713</td>
#       <td>3.042709</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>16.867304</td>
#       <td>3.028591</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr2_Wet_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>27.331293</td>
#       <td>16.125202</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.345000</td>
#       <td>6.802092</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>15.703065</td>
#       <td>5.689664</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>20.100551</td>
#       <td>9.294807</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>28.674623</td>
#       <td>17.128654</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>34.624049</td>
#       <td>23.033611</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>36.244461</td>
#       <td>24.457903</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr2_Wet_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>27.881481</td>
#       <td>14.244138</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.118062</td>
#       <td>7.342092</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>16.856361</td>
#       <td>3.012302</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>20.846632</td>
#       <td>6.950041</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>28.914499</td>
#       <td>15.130807</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>34.796067</td>
#       <td>21.644856</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>37.117233</td>
#       <td>23.513966</td>
#     </tr>
#   </tbody>
# </table>

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr2_Dry_AveDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr2_Dry_AveDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr2_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr2_Wet_AveDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr2_Dry_AveDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr2_Dry_AveDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr2_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr2_Wet_AveDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ## Projection Period 3: 2071-2100

# %% [markdown]
# Read in the CMIP5 values - these are all that are available for a projection period

# %%
CDateRange = '2071-2100'

# %%
inFile = os.path.normpath( os.path.join( CIN_DIR4, LWET_AVE_4 ))
LDPr3_Wet_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR4, LDRY_AVE_4 ))
LDPr3_Dry_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR4, BWET_AVE_4 ))
BDPr3_Wet_AveDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR4, BDRY_AVE_4 ))
BDPr3_Dry_AveDF = pd.read_pickle( inFile )

# %%
display( HTML( LDPr3_Dry_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>19.748281</td>
#       <td>3.027097</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>19.747005</td>
#       <td>3.007013</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>19.750278</td>
#       <td>2.991868</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>19.758032</td>
#       <td>2.981628</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>19.770193</td>
#       <td>2.976237</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr3_Dry_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>19.792503</td>
#       <td>2.539080</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>19.791218</td>
#       <td>2.518625</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>19.793983</td>
#       <td>2.502930</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>19.800732</td>
#       <td>2.491955</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>19.811398</td>
#       <td>2.485657</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr3_Dry_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>30.786051</td>
#       <td>15.230478</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.070711</td>
#       <td>8.212111</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>19.747005</td>
#       <td>2.975664</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>23.865185</td>
#       <td>7.170197</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>31.791643</td>
#       <td>15.662946</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>37.729523</td>
#       <td>23.628268</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>39.828659</td>
#       <td>25.982067</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr3_Dry_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>30.213539</td>
#       <td>14.701567</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>6.802122</td>
#       <td>8.156250</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>19.791218</td>
#       <td>2.484002</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>23.488844</td>
#       <td>6.599503</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>31.088288</td>
#       <td>15.321750</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>36.795788</td>
#       <td>23.085760</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>39.196247</td>
#       <td>25.101028</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr3_Wet_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>16.731098</td>
#       <td>6.621491</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16.704262</td>
#       <td>6.590991</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16.682154</td>
#       <td>6.564517</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16.664747</td>
#       <td>6.542009</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>16.652020</td>
#       <td>6.523423</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr3_Wet_AveDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>17.654989</td>
#       <td>3.543313</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17.656622</td>
#       <td>3.519409</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17.662506</td>
#       <td>3.500087</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>17.672550</td>
#       <td>3.485286</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>17.686651</td>
#       <td>3.474941</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr3_Wet_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>28.344406</td>
#       <td>17.053539</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.336354</td>
#       <td>6.875857</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>16.640499</td>
#       <td>6.487328</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>21.071601</td>
#       <td>10.110214</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>29.865559</td>
#       <td>18.184582</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>35.541082</td>
#       <td>23.965573</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>37.154095</td>
#       <td>25.479151</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr3_Wet_AveDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>28.692518</td>
#       <td>14.895101</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>7.137352</td>
#       <td>7.484088</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>17.654989</td>
#       <td>3.467377</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>21.573329</td>
#       <td>7.419465</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>29.842523</td>
#       <td>15.850523</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>35.576379</td>
#       <td>22.435845</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>37.924091</td>
#       <td>24.297657</td>
#     </tr>
#   </tbody>
# </table>

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr3_Dry_AveDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr3_Dry_AveDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr3_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr3_Wet_AveDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr3_Dry_AveDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr3_Dry_AveDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr3_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr3_Wet_AveDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Averages, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ## Compare CMIP5

# %% [markdown]
# ### LOCA

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDP_Dry_AveDF.plot( y="Tmax_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Dry_AveDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Dry_AveDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Dry_AveDF.plot( y="Tmax_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "LOCA Dry State, Smoothed Daily Averages", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDP_Dry_AveDF.plot( y="Tmax_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Dry_AveDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Dry_AveDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Dry_AveDF.plot( y="Tmax_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDP_Wet_AveDF.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Wet_AveDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Wet_AveDF.plot( y="Tmax_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "LOCA Wet State, Smoothed Daily Averages", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDP_Wet_AveDF.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Wet_AveDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Wet_AveDF.plot( y="Tmax_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_WAVE.plot( y="Tmax_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 label='PRISM 1981-2010')
PRISM_WAVE.plot( y="Tmin_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 linestyle='-.', label='PRISM 1981-2010')
LDP_Wet_AveDF.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                    label='Tmax 1981-2010' )
LDP_Wet_AveDF.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                    linestyle='-.', label='Tmin 1981-2010' )
LDPr1_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label='Tmax 2011-2040' )
LDPr1_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='Tmin 2011-2040' )
LDPr2_Wet_AveDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label='Tmax 2041-2070' )
LDPr2_Wet_AveDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='Tmin 2041-2070' )
LDPr3_Wet_AveDF.plot( y="Tmax_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
                      label='Tmax 2071-2100' )
LDPr3_Wet_AveDF.plot( y="Tmin_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='Tmin 2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Max and Min Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "LOCA Wet State, Smoothed Daily Averages", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_WAVE.plot( y="Tmax_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 label='PRISM 1981-2010')
PRISM_WAVE.plot( y="Tmin_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 linestyle='-.', label='PRISM 1981-2010')
LDP_Wet_AveDF.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                    label='Tmax 1981-2010' )
LDP_Wet_AveDF.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                    linestyle='-.', label='Tmin 1981-2010' )
LDPr1_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label='Tmax 2011-2040' )
LDPr1_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='Tmin 2011-2040' )
LDPr2_Wet_AveDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label='Tmax 2041-2070' )
LDPr2_Wet_AveDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='Tmin 2041-2070' )
LDPr3_Wet_AveDF.plot( y="Tmax_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
                      label='Tmax 2071-2100' )
LDPr3_Wet_AveDF.plot( y="Tmin_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='Tmin 2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Max and Min Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_ylim( (0.0, 50.0))
ax11.legend( loc='best')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_DAVE.plot( y="Tmax_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 label='PRISM')
PRISM_DAVE.plot( y="Tmin_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 linestyle='-.', label='PRISM')
LDP_Dry_AveDF.plot( y="Tmax_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
                    label='Tmax 1981-2010' )
LDP_Dry_AveDF.plot( y="Tmin_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
                    linestyle='-.', label='Tmin 1981-2010' )
LDPr1_Dry_AveDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label='Tmax 2011-2040' )
LDPr1_Dry_AveDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='Tmin 2011-2040' )
LDPr2_Dry_AveDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label='Tmax 2041-2070' )
LDPr2_Dry_AveDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='Tmin 2041-2070' )
LDPr3_Dry_AveDF.plot( y="Tmax_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
                      label='Tmax 2071-2100' )
LDPr3_Dry_AveDF.plot( y="Tmin_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='Tmin 2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Max and Min Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "LOCA Dry State, Smoothed Daily Averages", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
NewFigName = os.path.normpath( os.path.join( r'C:\Users\nmartin\Documents\CC_IRD\Figures', "FSmoothTemps.svg" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 12.0)
ax11 = Fig1.add_subplot(211)
PRISM_WAVE.plot( y="Tmax_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 label='PRISM Max. 1981-2010')
PRISM_WAVE.plot( y="Tmin_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 linestyle='-.', label='PRISM Min. 1981-2010')
LDP_Wet_AveDF.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                    label='LOCA Max. 1981-2010' )
LDP_Wet_AveDF.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                    linestyle='-.', label='LOCA Min. 1981-2010' )
LDPr1_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label='LOCA Max. 2011-2040' )
LDPr1_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='LOCA Min. 2011-2040' )
LDPr2_Wet_AveDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label='LOCA Max. 2041-2070' )
LDPr2_Wet_AveDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='LOCA Min. 2041-2070' )
LDPr3_Wet_AveDF.plot( y="Tmax_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
                      label='LOCA Max. 2071-2100' )
LDPr3_Wet_AveDF.plot( y="Tmin_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
                      linestyle='-.', label='LOCA Min. 2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Wet State Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_ylim( (0.0, 50.0))
ax11.legend( loc='best')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )
# plot 2
ax21 = Fig1.add_subplot(212)
PRISM_DAVE.plot( y="Tmax_C", color='xkcd:black', linewidth=2.0, ax=ax21, 
                 label='PRISM Max. 1981-2010')
PRISM_DAVE.plot( y="Tmin_C", color='xkcd:black', linewidth=2.0, ax=ax21, 
                 linestyle='-.', label='PRISM Min. 1981-2010')
LDP_Dry_AveDF.plot( y="Tmax_C", color='xkcd:dark orange', linewidth=2.0, ax=ax21, 
                    label='LOCA Max. 1981-2010' )
LDP_Dry_AveDF.plot( y="Tmin_C", color='xkcd:dark orange', linewidth=2.0, ax=ax21, 
                    linestyle='-.', label='LOCA Min. 1981-2010' )
LDPr1_Dry_AveDF.plot( y="Tmax_C", color='xkcd:orange brown', linewidth=2.0, ax=ax21, 
                      label='LOCA Max. 2011-2040' )
LDPr1_Dry_AveDF.plot( y="Tmin_C", color='xkcd:orange brown', linewidth=2.0, ax=ax21, 
                      linestyle='-.', label='LOCA Min. 2011-2040' )
LDPr2_Dry_AveDF.plot( y="Tmax_C", color='xkcd:orange', linewidth=2.0, ax=ax21, 
                      label='LOCA Max. 2041-2070' )
LDPr2_Dry_AveDF.plot( y="Tmin_C", color='xkcd:orange', linewidth=2.0, ax=ax21, 
                      linestyle='-.', label='LOCA Min. 2041-2070' )
LDPr3_Dry_AveDF.plot( y="Tmax_C", color='xkcd:light orange', linewidth=2.0, ax=ax21, 
                      label='LOCA Max. 2071-2100' )
LDPr3_Dry_AveDF.plot( y="Tmin_C", color='xkcd:light orange', linewidth=2.0, ax=ax21, 
                      linestyle='-.', label='LOCA Min. 2071-2100' )
ax21.set_ylim( (0.0, 50.0))
ax21.set_xlabel('Day of the Year', fontsize=14 )
ax21.set_ylabel('Daily Dry State Temperature ($ ^{\circ} C$)', fontsize=14)
ax21.legend()
ax21.tick_params(axis='both', which='major', labelsize=13)
ax21.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax21.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )
Fig1.savefig( NewFigName )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDP_Dry_AveDF.plot( y="Tmin_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Dry_AveDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Dry_AveDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Dry_AveDF.plot( y="Tmin_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "LOCA Dry State, Smoothed Daily Averages", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDP_Dry_AveDF.plot( y="Tmin_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Dry_AveDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Dry_AveDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Dry_AveDF.plot( y="Tmin_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDP_Wet_AveDF.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Wet_AveDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Wet_AveDF.plot( y="Tmin_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "LOCA Wet State, Smoothed Daily Averages", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDP_Wet_AveDF.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Wet_AveDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Wet_AveDF.plot( y="Tmin_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ### BCCA

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
BDP_Dry_AveDF.plot( y="Tmax_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
BDPr1_Dry_AveDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
BDPr2_Dry_AveDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
BDPr3_Dry_AveDF.plot( y="Tmax_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "BCCA Dry State, Smoothed Daily Averages", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
BDP_Wet_AveDF.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
BDPr1_Wet_AveDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
BDPr2_Wet_AveDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
BDPr3_Wet_AveDF.plot( y="Tmax_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "BCCA Wet State, Smoothed Daily Averages", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
BDP_Dry_AveDF.plot( y="Tmin_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
BDPr1_Dry_AveDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
BDPr2_Dry_AveDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
BDPr3_Dry_AveDF.plot( y="Tmin_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "BCCA Dry State, Smoothed Daily Averages", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
BDP_Wet_AveDF.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
BDPr1_Wet_AveDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
BDPr2_Wet_AveDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
BDPr3_Wet_AveDF.plot( y="Tmin_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "BCCA Wet State, Smoothed Daily Averages", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ## Inter-Period Differences

# %% [markdown]
# Create a DataFrame with the inter-period differences

# %%
DataDict = { "PRISM_Comp" : np.array( PRISM_WAVE["Tmax_C"] - LDP_Wet_AveDF["Tmax_C"], 
                                     dtype=np.float32 ),
             "PPeriod_1" : np.array( LDPr1_Wet_AveDF["Tmax_C"] - LDP_Wet_AveDF["Tmax_C"], 
                                     dtype=np.float32 ),
             "PPeriod_2" : np.array( LDPr2_Wet_AveDF["Tmax_C"] - LDPr1_Wet_AveDF["Tmax_C"], 
                                     dtype=np.float32 ),
             "PPeriod_3" : np.array( LDPr3_Wet_AveDF["Tmax_C"] - LDPr2_Wet_AveDF["Tmax_C"], 
                                     dtype=np.float32 ),
           }
LOWetAveMaxDF = pd.DataFrame( index=LDP_Wet_AveDF.index, data=DataDict )

# %%
display( HTML( LOWetAveMaxDF.describe().to_html() ) )

# %%
DataDict = { "PRISM_Comp" : np.array( PRISM_WAVE["Tmin_C"] - LDP_Wet_AveDF["Tmin_C"], 
                                     dtype=np.float32 ),
             "PPeriod_1" : np.array( LDPr1_Wet_AveDF["Tmin_C"] - LDP_Wet_AveDF["Tmin_C"], 
                                     dtype=np.float32 ),
             "PPeriod_2" : np.array( LDPr2_Wet_AveDF["Tmin_C"] - LDPr1_Wet_AveDF["Tmin_C"], 
                                     dtype=np.float32 ),
             "PPeriod_3" : np.array( LDPr3_Wet_AveDF["Tmin_C"] - LDPr2_Wet_AveDF["Tmin_C"], 
                                     dtype=np.float32 ),
           }
LOWetAveMinDF = pd.DataFrame( index=LDP_Wet_AveDF.index, data=DataDict )

# %%
display( HTML( LOWetAveMinDF.describe().to_html() ) )

# %%
DataDict = { "PRISM_Comp" : np.array( PRISM_DAVE["Tmax_C"] - LDP_Dry_AveDF["Tmax_C"], 
                                     dtype=np.float32 ),
             "PPeriod_1" : np.array( LDPr1_Dry_AveDF["Tmax_C"] - LDP_Dry_AveDF["Tmax_C"], 
                                     dtype=np.float32 ),
             "PPeriod_2" : np.array( LDPr2_Dry_AveDF["Tmax_C"] - LDPr1_Dry_AveDF["Tmax_C"], 
                                     dtype=np.float32 ),
             "PPeriod_3" : np.array( LDPr3_Dry_AveDF["Tmax_C"] - LDPr2_Dry_AveDF["Tmax_C"], 
                                     dtype=np.float32 ),
           }
LODryAveMaxDF = pd.DataFrame( index=LDP_Dry_AveDF.index, data=DataDict )

# %%
display( HTML( LODryAveMaxDF.describe().to_html() ) )

# %%
DataDict = { "PRISM_Comp" : np.array( PRISM_DAVE["Tmin_C"] - LDP_Dry_AveDF["Tmin_C"], 
                                     dtype=np.float32 ),
             "PPeriod_1" : np.array( LDPr1_Dry_AveDF["Tmin_C"] - LDP_Dry_AveDF["Tmin_C"], 
                                     dtype=np.float32 ),
             "PPeriod_2" : np.array( LDPr2_Dry_AveDF["Tmin_C"] - LDPr1_Dry_AveDF["Tmin_C"], 
                                     dtype=np.float32 ),
             "PPeriod_3" : np.array( LDPr3_Dry_AveDF["Tmin_C"] - LDPr2_Dry_AveDF["Tmin_C"], 
                                     dtype=np.float32 ),
           }
LODryAveMinDF = pd.DataFrame( index=LDP_Dry_AveDF.index, data=DataDict )

# %%
display( HTML( LODryAveMinDF.describe().to_html() ) )

# %% [markdown]
# Output to Excel

# %%
OutFiler = os.path.normpath( os.path.join( OUT_DIR, "LOCA_Periods_AveDiff.xlsx"))
with pd.ExcelWriter( OutFiler ) as writer:
    LOWetAveMaxDF.to_excel( writer, sheet_name="Wet_MaxT_Ave_Delta", na_rep=str(np.nan),
                            index=True, index_label="DayOfYear" )
    LOWetAveMinDF.to_excel( writer, sheet_name="Wet_MinT_Ave_Delta", na_rep=str(np.nan),
                            index=True, index_label="DayOfYear" )
    LODryAveMaxDF.to_excel( writer, sheet_name="Dry_MaxT_Ave_Delta", na_rep=str(np.nan),
                            index=True, index_label="DayOfYear" )
    LODryAveMinDF.to_excel( writer, sheet_name="Dry_MinT_Ave_Delta", na_rep=str(np.nan),
                            index=True, index_label="DayOfYear" )
