# %% [markdown]
# # Comparison of Smoothed Day of the Year Deviations

# %% [markdown]
# Fourier series smoothing was used to create day of the year standard deviation values for "other weather" parameters from each of the available data sets and time periods.

# %% [markdown]
# The available data sets and parameters are enumerated below.
#
# - PRISM
#     - Maximum daily air temperature
#     - Average daily air temperature, provided as the average between the maximum and the minimum
#     - Minimum daily air temperature
#     - Relative humidity, calculated from dew point temperatuer and vapor pressure deficit
# - CMIP5, LOCA downscaling
#     - Maximum daily air temperature
#     - Minimum daily air temperature
# - CMIP5, BCCA downscaling
#     - Maximum daily air temperature
#     - Minimum daily air temperature

# %% [markdown]
# Climate periods:
#
# 1. Data period: 1981-2010
# 2. Projection period 1: 2011-2040
# 3. Projection period 2: 2041-2070
# 4. Projection period 3: 2071-2100

# %%
# %matplotlib inline

# %%
import os
from IPython.display import display, HTML
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
CIN_DIR1 = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
          r'otes\Processed\CMIP5\OtherWeather_1981-2010'
CIN_DIR2 = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
          r'otes\Processed\CMIP5\OtherWeather_2011-2040'
CIN_DIR3 = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
          r'otes\Processed\CMIP5\OtherWeather_2041-2070'
CIN_DIR4 = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
          r'otes\Processed\CMIP5\OtherWeather_2071-2100'

# %%
LDRY_Std_1 = "OWeath_LOCA_Dry_Smooth_Std_1981-2010.pickle"
LWET_Std_1 = "OWeath_LOCA_Wet_Smooth_Std_1981-2010.pickle"
LDRY_Std_2 = "OWeath_LOCA_Dry_Smooth_Std_2011-2040.pickle"
LWET_Std_2 = "OWeath_LOCA_Wet_Smooth_Std_2011-2040.pickle"
LDRY_Std_3 = "OWeath_LOCA_Dry_Smooth_Std_2041-2070.pickle"
LWET_Std_3 = "OWeath_LOCA_Wet_Smooth_Std_2041-2070.pickle"
LDRY_Std_4 = "OWeath_LOCA_Dry_Smooth_Std_2071-2100.pickle"
LWET_Std_4 = "OWeath_LOCA_Wet_Smooth_Std_2071-2100.pickle"

# %%
BDRY_Std_1 = "OWeath_BCCA_Dry_Smooth_Std_1981-2010.pickle"
BWET_Std_1 = "OWeath_BCCA_Wet_Smooth_Std_1981-2010.pickle"
BDRY_Std_2 = "OWeath_BCCA_Dry_Smooth_Std_2011-2040.pickle"
BWET_Std_2 = "OWeath_BCCA_Wet_Smooth_Std_2011-2040.pickle"
BDRY_Std_3 = "OWeath_BCCA_Dry_Smooth_Std_2041-2070.pickle"
BWET_Std_3 = "OWeath_BCCA_Wet_Smooth_Std_2041-2070.pickle"
BDRY_Std_4 = "OWeath_BCCA_Dry_Smooth_Std_2071-2100.pickle"
BWET_Std_4 = "OWeath_BCCA_Wet_Smooth_Std_2071-2100.pickle"

# %%
PRIS_IN_DIR = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
              r'otes\Processed\PRISM\Other_Weather'

# %%
PDRY_Std = "OWeath_Dry_Smooth_Std_1981-2010.pickle"
PWET_Std = "OWeath_Wet_Smooth_Std_1981-2010.pickle"

# %%
OUT_DIR = r'\\augustine.space.swri.edu\jdrive\Groundwater\R8937_Stochastic_CC_Recharge\Data\JN' \
          r'otes\Processed\CMIP5'

# %% [markdown]
# ## Data Period: 1981 - 2010

# %% [markdown]
# This is the only time period that has PRISM data and the downscaled climate model results

# %% [markdown]
# Read in the PRISM files

# %%
inFile = os.path.normpath( os.path.join( PRIS_IN_DIR, PDRY_Std ) )
PRISM_DStd = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( PRIS_IN_DIR, PWET_Std ) )
PRISM_WStd = pd.read_pickle( inFile )

# %%
display( HTML( PRISM_DStd.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmean_C</th>
#       <th>Tmin_C</th>
#       <th>DewPtT_C</th>
#       <th>RelHum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.735632</td>
#       <td>4.485643</td>
#       <td>4.539785</td>
#       <td>6.032092</td>
#       <td>14.879992</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.749336</td>
#       <td>4.482987</td>
#       <td>4.526789</td>
#       <td>6.016781</td>
#       <td>14.888462</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.761966</td>
#       <td>4.479940</td>
#       <td>4.513986</td>
#       <td>6.001184</td>
#       <td>14.896061</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.773521</td>
#       <td>4.476523</td>
#       <td>4.501394</td>
#       <td>5.985331</td>
#       <td>14.902763</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
display( HTML( PRISM_DStd.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmean_C</th>
#       <th>Tmin_C</th>
#       <th>DewPtT_C</th>
#       <th>RelHum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.840539</td>
#       <td>3.294615</td>
#       <td>3.692805</td>
#       <td>4.479619</td>
#       <td>11.911390</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.313383</td>
#       <td>1.086107</td>
#       <td>1.309021</td>
#       <td>1.777265</td>
#       <td>2.722467</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.940233</td>
#       <td>1.463136</td>
#       <td>1.373349</td>
#       <td>1.577030</td>
#       <td>7.522561</td>
#     </tr>
#     <tr>
# ...

# %%
display( HTML( PRISM_WStd.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmean_C</th>
#       <th>Tmin_C</th>
#       <th>DewPtT_C</th>
#       <th>RelHum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.568180</td>
#       <td>4.634019</td>
#       <td>4.847625</td>
#       <td>5.729281</td>
#       <td>13.667857</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.567241</td>
#       <td>4.631791</td>
#       <td>4.843236</td>
#       <td>5.735912</td>
#       <td>13.719524</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.566419</td>
#       <td>4.629185</td>
#       <td>4.838006</td>
#       <td>5.741141</td>
#       <td>13.768963</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.565692</td>
#       <td>4.626179</td>
#       <td>4.831920</td>
#       <td>5.744904</td>
#       <td>13.815982</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
display( HTML( PRISM_WStd.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmean_C</th>
#       <th>Tmin_C</th>
#       <th>DewPtT_C</th>
#       <th>RelHum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>4.395838</td>
#       <td>3.385248</td>
#       <td>3.301956</td>
#       <td>3.493980</td>
#       <td>11.219335</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.120951</td>
#       <td>1.088297</td>
#       <td>1.313724</td>
#       <td>1.575165</td>
#       <td>1.751505</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.717749</td>
#       <td>1.848326</td>
#       <td>1.170178</td>
#       <td>1.273695</td>
#       <td>8.411937</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Read in the CMIP5, both types of downscaling

# %%
inFile = os.path.normpath( os.path.join( CIN_DIR1, LWET_Std_1 ))
LDP_Wet_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR1, LDRY_Std_1 ))
LDP_Dry_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR1, BWET_Std_1 ))
BDP_Wet_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR1, BDRY_Std_1 ))
BDP_Dry_StdDF = pd.read_pickle( inFile )

# %%
display( HTML( LDP_Dry_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.178154</td>
#       <td>5.316839</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.197138</td>
#       <td>5.328569</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.215878</td>
#       <td>5.340088</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.234354</td>
#       <td>5.351372</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.252542</td>
#       <td>5.362396</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDP_Dry_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>4.794377</td>
#       <td>4.909475</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.811312</td>
#       <td>4.914529</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.827685</td>
#       <td>4.919476</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.843482</td>
#       <td>4.924304</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4.858687</td>
#       <td>4.928992</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDP_Dry_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.802443</td>
#       <td>3.834327</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.177601</td>
#       <td>1.340630</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.074489</td>
#       <td>1.720370</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.673266</td>
#       <td>2.463230</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.822775</td>
#       <td>4.205258</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.893194</td>
#       <td>5.050565</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.569902</td>
#       <td>5.501451</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDP_Dry_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.096844</td>
#       <td>3.318520</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.221008</td>
#       <td>1.412844</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.565122</td>
#       <td>1.228914</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1.878790</td>
#       <td>1.786009</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>2.929435</td>
#       <td>3.655236</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.285223</td>
#       <td>4.732838</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.019034</td>
#       <td>4.972040</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDP_Wet_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.336935</td>
#       <td>5.644661</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.343153</td>
#       <td>5.649313</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.350105</td>
#       <td>5.654217</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.357778</td>
#       <td>5.659359</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.366147</td>
#       <td>5.664725</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDP_Wet_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.277365</td>
#       <td>5.247494</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.288605</td>
#       <td>5.250721</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.299282</td>
#       <td>5.253718</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.309381</td>
#       <td>5.256468</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.318889</td>
#       <td>5.258955</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDP_Wet_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>4.228781</td>
#       <td>3.852946</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.096716</td>
#       <td>1.531160</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.832484</td>
#       <td>1.859139</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>3.010586</td>
#       <td>2.156732</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>4.192865</td>
#       <td>3.907472</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>5.357092</td>
#       <td>5.546192</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.764861</td>
#       <td>5.787924</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDP_Wet_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.420696</td>
#       <td>3.332583</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.298255</td>
#       <td>1.482290</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.899895</td>
#       <td>1.370049</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.023497</td>
#       <td>1.716238</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.280042</td>
#       <td>3.398482</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.721240</td>
#       <td>4.893904</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.382820</td>
#       <td>5.267459</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Plot the wet and dry periods

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_DStd.plot( y="Tmax_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Dry_StdDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
BDP_Dry_StdDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                    label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Std, 1981-2011", fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_WStd.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Wet_StdDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
BDP_Wet_StdDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                    label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Std, 1981-2011", fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_DStd.plot( y="Tmin_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Dry_StdDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
BDP_Dry_StdDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                    label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Std, 1981-2011", fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_WStd.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Wet_StdDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                    label="LOCA" )
BDP_Wet_StdDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                    label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Std, 1981-2011", fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ## Projection Period 1: 2011-2040

# %% [markdown]
# Read in the CMIP5 values - these are all that are available for a projection period

# %%
CDateRange = '2011-2040'

# %%
inFile = os.path.normpath( os.path.join( CIN_DIR2, LWET_Std_2 ))
LDPr1_Wet_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR2, LDRY_Std_2 ))
LDPr1_Dry_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR2, BWET_Std_2 ))
BDPr1_Wet_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR2, BDRY_Std_2 ))
BDPr1_Dry_StdDF = pd.read_pickle( inFile )

# %%
display( HTML( LDPr1_Dry_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.168464</td>
#       <td>5.341741</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.183464</td>
#       <td>5.351669</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.198294</td>
#       <td>5.361452</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.212944</td>
#       <td>5.371071</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.227405</td>
#       <td>5.380511</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr1_Dry_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>4.734928</td>
#       <td>4.887410</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.752472</td>
#       <td>4.892125</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.769556</td>
#       <td>4.896851</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.786158</td>
#       <td>4.901568</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4.802262</td>
#       <td>4.906263</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr1_Dry_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.852084</td>
#       <td>3.881410</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.149241</td>
#       <td>1.324023</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.113317</td>
#       <td>1.802487</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.776046</td>
#       <td>2.527756</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.873811</td>
#       <td>4.216552</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.942501</td>
#       <td>5.115450</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.523720</td>
#       <td>5.514305</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr1_Dry_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.097113</td>
#       <td>3.345886</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.190488</td>
#       <td>1.388116</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.618804</td>
#       <td>1.311159</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1.917407</td>
#       <td>1.842686</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>2.912829</td>
#       <td>3.647259</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.245220</td>
#       <td>4.764459</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>4.995699</td>
#       <td>4.966783</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr1_Wet_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.421393</td>
#       <td>5.687822</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.422856</td>
#       <td>5.690640</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.424847</td>
#       <td>5.693745</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.427369</td>
#       <td>5.697126</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.430415</td>
#       <td>5.700772</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr1_Wet_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.263912</td>
#       <td>5.296592</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.275645</td>
#       <td>5.298516</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.286946</td>
#       <td>5.300185</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.297800</td>
#       <td>5.301585</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.308193</td>
#       <td>5.302702</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr1_Wet_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>4.327842</td>
#       <td>3.898411</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.042673</td>
#       <td>1.518524</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.979674</td>
#       <td>1.942754</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>3.216779</td>
#       <td>2.211276</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>4.309186</td>
#       <td>3.907375</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>5.445168</td>
#       <td>5.608151</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.691827</td>
#       <td>5.805312</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr1_Wet_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.466330</td>
#       <td>3.374236</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.282690</td>
#       <td>1.466700</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.984437</td>
#       <td>1.445994</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.080127</td>
#       <td>1.776551</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.300810</td>
#       <td>3.412663</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.772869</td>
#       <td>4.921625</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.399345</td>
#       <td>5.304214</td>
#     </tr>
#   </tbody>
# </table>

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr1_Dry_StdDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr1_Dry_StdDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr1_Wet_StdDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr1_Wet_StdDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr1_Dry_StdDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr1_Dry_StdDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr1_Wet_StdDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr1_Wet_StdDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ## Projection Period 2: 2041-2070

# %% [markdown]
# Read in the CMIP5 values - these are all that are available for a projection period

# %%
CDateRange = '2041-2070'

# %%
inFile = os.path.normpath( os.path.join( CIN_DIR3, LWET_Std_3 ))
LDPr2_Wet_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR3, LDRY_Std_3 ))
LDPr2_Dry_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR3, BWET_Std_3 ))
BDPr2_Wet_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR3, BDRY_Std_3 ))
BDPr2_Dry_StdDF = pd.read_pickle( inFile )

# %%
display( HTML( LDPr2_Dry_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.167929</td>
#       <td>5.287189</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.183767</td>
#       <td>5.297938</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.199494</td>
#       <td>5.308623</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.215096</td>
#       <td>5.319218</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.230552</td>
#       <td>5.329695</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr2_Dry_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>4.666184</td>
#       <td>4.882843</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.684054</td>
#       <td>4.887254</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.701452</td>
#       <td>4.891499</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.718350</td>
#       <td>4.895563</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4.734728</td>
#       <td>4.899432</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr2_Dry_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.906865</td>
#       <td>3.919801</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.111519</td>
#       <td>1.270299</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.221542</td>
#       <td>1.950303</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.854455</td>
#       <td>2.584206</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.963175</td>
#       <td>4.271669</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.933587</td>
#       <td>5.072736</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.533842</td>
#       <td>5.483682</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr2_Dry_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.142408</td>
#       <td>3.396121</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.101635</td>
#       <td>1.295254</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.783415</td>
#       <td>1.490233</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.036354</td>
#       <td>1.989241</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>2.997119</td>
#       <td>3.704877</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.178949</td>
#       <td>4.686703</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>4.921465</td>
#       <td>4.925704</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr2_Wet_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.364813</td>
#       <td>5.670689</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.369127</td>
#       <td>5.671381</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.374024</td>
#       <td>5.672248</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.379488</td>
#       <td>5.673281</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.385501</td>
#       <td>5.674470</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr2_Wet_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.222610</td>
#       <td>5.274291</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.236165</td>
#       <td>5.276597</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.249177</td>
#       <td>5.278456</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.261623</td>
#       <td>5.279853</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.273486</td>
#       <td>5.280775</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr2_Wet_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>4.353158</td>
#       <td>3.912740</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.978742</td>
#       <td>1.450833</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>3.079771</td>
#       <td>2.021778</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>3.329788</td>
#       <td>2.291048</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>4.335232</td>
#       <td>3.927573</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>5.385229</td>
#       <td>5.536194</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.662426</td>
#       <td>5.700475</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr2_Wet_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.495443</td>
#       <td>3.406992</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.195131</td>
#       <td>1.366184</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.124736</td>
#       <td>1.612822</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.204165</td>
#       <td>1.917203</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.330209</td>
#       <td>3.450051</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.673096</td>
#       <td>4.806008</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.368175</td>
#       <td>5.281209</td>
#     </tr>
#   </tbody>
# </table>

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr2_Dry_StdDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr2_Dry_StdDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr2_Wet_StdDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr2_Wet_StdDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr2_Dry_StdDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr2_Dry_StdDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr2_Wet_StdDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr2_Wet_StdDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ## Projection Period 3: 2071-2100

# %% [markdown]
# Read in the CMIP5 values - these are all that are available for a projection period

# %%
CDateRange = '2071-2100'

# %%
inFile = os.path.normpath( os.path.join( CIN_DIR4, LWET_Std_4 ))
LDPr3_Wet_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR4, LDRY_Std_4 ))
LDPr3_Dry_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR4, BWET_Std_4 ))
BDPr3_Wet_StdDF = pd.read_pickle( inFile )
inFile = os.path.normpath( os.path.join( CIN_DIR4, BDRY_Std_4 ))
BDPr3_Dry_StdDF = pd.read_pickle( inFile )

# %%
display( HTML( LDPr3_Dry_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.332584</td>
#       <td>5.427135</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.347401</td>
#       <td>5.436644</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.361939</td>
#       <td>5.445939</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.376186</td>
#       <td>5.454999</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.390128</td>
#       <td>5.463806</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr3_Dry_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>4.728499</td>
#       <td>4.938420</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.744107</td>
#       <td>4.942368</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.759291</td>
#       <td>4.946103</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.774023</td>
#       <td>4.949609</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4.788284</td>
#       <td>4.952872</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr3_Dry_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>4.112074</td>
#       <td>4.123702</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.038785</td>
#       <td>1.166234</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.521225</td>
#       <td>2.289254</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>3.158623</td>
#       <td>2.911658</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>4.136429</td>
#       <td>4.443810</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>5.099488</td>
#       <td>5.190363</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.622103</td>
#       <td>5.561902</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr3_Dry_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.402272</td>
#       <td>3.630481</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.945476</td>
#       <td>1.122415</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.254680</td>
#       <td>1.983233</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.439784</td>
#       <td>2.400012</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.283950</td>
#       <td>3.898048</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.282459</td>
#       <td>4.740536</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>4.941822</td>
#       <td>4.969488</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr3_Wet_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.544048</td>
#       <td>5.790057</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.546252</td>
#       <td>5.790579</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.548888</td>
#       <td>5.791136</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.551954</td>
#       <td>5.791721</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.555441</td>
#       <td>5.792322</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr3_Wet_StdDF.head().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5.178545</td>
#       <td>5.205127</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.189299</td>
#       <td>5.204325</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.199686</td>
#       <td>5.203171</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.209685</td>
#       <td>5.201666</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.219281</td>
#       <td>5.199801</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( LDPr3_Wet_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>4.521033</td>
#       <td>4.038086</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.916399</td>
#       <td>1.375857</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>3.408697</td>
#       <td>2.298614</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>3.566158</td>
#       <td>2.498168</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>4.438757</td>
#       <td>3.990711</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>5.545911</td>
#       <td>5.564090</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.745275</td>
#       <td>5.796251</td>
#     </tr>
#   </tbody>
# </table>

# %%
display( HTML( BDPr3_Wet_StdDF.describe().to_html() ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tmax_C</th>
#       <th>Tmin_C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>366.000000</td>
#       <td>366.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.702353</td>
#       <td>3.588601</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.044038</td>
#       <td>1.184977</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.481408</td>
#       <td>2.041687</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.578185</td>
#       <td>2.313226</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.572597</td>
#       <td>3.599602</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.745811</td>
#       <td>4.810183</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.303461</td>
#       <td>5.205699</td>
#     </tr>
#   </tbody>
# </table>

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr3_Dry_StdDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr3_Dry_StdDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr3_Wet_StdDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr3_Wet_StdDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr3_Dry_StdDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr3_Dry_StdDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Dry State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
LDPr3_Wet_StdDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
                      label="LOCA" )
BDPr3_Wet_StdDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
                      label="BCCA" )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title("Wet State - Smoothed Std, %s" % CDateRange, fontsize=16)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ## Compare CMIP5

# %% [markdown]
# ### LOCA

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_DStd.plot( y="Tmax_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Dry_StdDF.plot( y="Tmax_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Dry_StdDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Dry_StdDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Dry_StdDF.plot( y="Tmax_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "LOCA Dry State, Smoothed Daily Std", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_WStd.plot( y="Tmax_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Wet_StdDF.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Wet_StdDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Wet_StdDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Wet_StdDF.plot( y="Tmax_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "LOCA Wet State, Smoothed Daily Std", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_DStd.plot( y="Tmin_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Dry_StdDF.plot( y="Tmin_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Dry_StdDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Dry_StdDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Dry_StdDF.plot( y="Tmin_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "LOCA Dry State, Smoothed Daily Std", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
PRISM_WStd.plot( y="Tmin_C", color='xkcd:black', linewidth=2.0, ax=ax11, 
                 label='PRISM')
LDP_Wet_StdDF.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
LDPr1_Wet_StdDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
LDPr2_Wet_StdDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
LDPr3_Wet_StdDF.plot( y="Tmin_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "LOCA Wet State, Smoothed Daily Std", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ### BCCA

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
BDP_Dry_StdDF.plot( y="Tmax_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
BDPr1_Dry_StdDF.plot( y="Tmax_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
BDPr2_Dry_StdDF.plot( y="Tmax_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
BDPr3_Dry_StdDF.plot( y="Tmax_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "BCCA Dry State, Smoothed Daily Std", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
BDP_Wet_StdDF.plot( y="Tmax_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
BDPr1_Wet_StdDF.plot( y="Tmax_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
BDPr2_Wet_StdDF.plot( y="Tmax_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
BDPr3_Wet_StdDF.plot( y="Tmax_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Maximum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "BCCA Wet State, Smoothed Daily Std", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
BDP_Dry_StdDF.plot( y="Tmin_C", color='xkcd:hunter green', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
BDPr1_Dry_StdDF.plot( y="Tmin_C", color='xkcd:olive green', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
BDPr2_Dry_StdDF.plot( y="Tmin_C", color='xkcd:green', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
BDPr3_Dry_StdDF.plot( y="Tmin_C", color='xkcd:lime green', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "BCCA Dry State, Smoothed Daily Std", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
BDP_Wet_StdDF.plot( y="Tmin_C", color='xkcd:navy', linewidth=2.0, ax=ax11, 
               label='1981-2010' )
BDPr1_Wet_StdDF.plot( y="Tmin_C", color='xkcd:royal blue', linewidth=2.0, ax=ax11, 
               label='2011-2040' )
BDPr2_Wet_StdDF.plot( y="Tmin_C", color='xkcd:sky blue', linewidth=2.0, ax=ax11, 
               label='2041-2070' )
BDPr3_Wet_StdDF.plot( y="Tmin_C", color='xkcd:aquamarine', linewidth=2.0, ax=ax11, 
               label='2071-2100' )
ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Daily Minimum Temperature ($ ^{\circ} C$)', fontsize=14)
ax11.set_title( "BCCA Wet State, Smoothed Daily Std", fontsize=16)
ax11.legend()
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.0f}" ) )

# %% [markdown]
# ## Inter-Period Differences

# %% [markdown]
# Create a DataFrame with the inter-period differences

# %%
DataDict = { "PPeriod_1" : np.array( LDPr1_Wet_StdDF["Tmax_C"] - LDP_Wet_StdDF["Tmax_C"], 
                                     dtype=np.float32 ),
             "PPeriod_2" : np.array( LDPr2_Wet_StdDF["Tmax_C"] - LDPr1_Wet_StdDF["Tmax_C"], 
                                     dtype=np.float32 ),
             "PPeriod_3" : np.array( LDPr3_Wet_StdDF["Tmax_C"] - LDPr2_Wet_StdDF["Tmax_C"], 
                                     dtype=np.float32 ),
           }
LOWetStdMaxDF = pd.DataFrame( index=LDP_Wet_StdDF.index, data=DataDict )

# %%
display( HTML( LOWetStdMaxDF.describe().to_html() ) )

# %%
DataDict = { "PPeriod_1" : np.array( LDPr1_Wet_StdDF["Tmin_C"] - LDP_Wet_StdDF["Tmin_C"], 
                                     dtype=np.float32 ),
             "PPeriod_2" : np.array( LDPr2_Wet_StdDF["Tmin_C"] - LDPr1_Wet_StdDF["Tmin_C"], 
                                     dtype=np.float32 ),
             "PPeriod_3" : np.array( LDPr3_Wet_StdDF["Tmin_C"] - LDPr2_Wet_StdDF["Tmin_C"], 
                                     dtype=np.float32 ),
           }
LOWetStdMinDF = pd.DataFrame( index=LDP_Wet_StdDF.index, data=DataDict )

# %%
display( HTML( LOWetStdMinDF.describe().to_html() ) )

# %%
DataDict = { "PPeriod_1" : np.array( LDPr1_Dry_StdDF["Tmax_C"] - LDP_Dry_StdDF["Tmax_C"], 
                                     dtype=np.float32 ),
             "PPeriod_2" : np.array( LDPr2_Dry_StdDF["Tmax_C"] - LDPr1_Dry_StdDF["Tmax_C"], 
                                     dtype=np.float32 ),
             "PPeriod_3" : np.array( LDPr3_Dry_StdDF["Tmax_C"] - LDPr2_Dry_StdDF["Tmax_C"], 
                                     dtype=np.float32 ),
           }
LODryStdMaxDF = pd.DataFrame( index=LDP_Dry_StdDF.index, data=DataDict )

# %%
display( HTML( LODryStdMaxDF.describe().to_html() ) )

# %%
DataDict = { "PPeriod_1" : np.array( LDPr1_Dry_StdDF["Tmin_C"] - LDP_Dry_StdDF["Tmin_C"], 
                                     dtype=np.float32 ),
             "PPeriod_2" : np.array( LDPr2_Dry_StdDF["Tmin_C"] - LDPr1_Dry_StdDF["Tmin_C"], 
                                     dtype=np.float32 ),
             "PPeriod_3" : np.array( LDPr3_Dry_StdDF["Tmin_C"] - LDPr2_Dry_StdDF["Tmin_C"], 
                                     dtype=np.float32 ),
           }
LODryStdMinDF = pd.DataFrame( index=LDP_Dry_StdDF.index, data=DataDict )

# %%
display( HTML( LODryStdMinDF.describe().to_html() ) )

# %% [markdown]
# Output the differences to Excel

# %%
OutFiler = os.path.normpath( os.path.join( OUT_DIR, "LOCA_Periods_StdDiff.xlsx"))
with pd.ExcelWriter( OutFiler ) as writer:
    LOWetStdMaxDF.to_excel( writer, sheet_name="Wet_MaxT_Std_Delta", na_rep=str(np.nan),
                            index=True, index_label="DayOfYear" )
    LOWetStdMinDF.to_excel( writer, sheet_name="Wet_MinT_Std_Delta", na_rep=str(np.nan),
                            index=True, index_label="DayOfYear" )
    LODryStdMaxDF.to_excel( writer, sheet_name="Dry_MaxT_Std_Delta", na_rep=str(np.nan),
                            index=True, index_label="DayOfYear" )
    LODryStdMinDF.to_excel( writer, sheet_name="Dry_MinT_Std_Delta", na_rep=str(np.nan),
                            index=True, index_label="DayOfYear" )
