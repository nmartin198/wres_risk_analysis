# %% [markdown]
# # Compare WG Projected Precipitation Depths

# %%
# %matplotlib inline

# %%
import os
from IPython.display import display, HTML
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import stats as sstats
import datetime as dt
import sqlalchemy
import seaborn as sns
from copy import deepcopy
import pickle

# %%
# input information for weather generators
#WG_IN_DIR = r'C:\Temp\WG_Test_Out\Test1\Processed\Comparison'
#WG_IN_DIR = r'C:\Temp\WG_Test_Out\Test2\Processed\Comparison'
WG_IN_DIR = r'C:\Temp\WG_Test_Out\Test3\Processed\Comparison'
#OUT_DIR = r'C:\Temp\WG_Test_Out\Test1\Processed\Comparison'
#OUT_DIR = r'C:\Temp\WG_Test_Out\Test2\Processed\Comparison'
OUT_DIR = r'C:\Temp\WG_Test_Out\Test3\Processed\Comparison'
H1_DATA_ROOT = "H1_Data_Depth_G"
H1_PROJ1_ROOT = "H1P1_Depth_G"
H1_PROJ2_ROOT = "H1P2_Depth_G"
H1_PROJ3_ROOT = "H1P3_Depth_G"
PLOT_DIR = "Plots_ProjComp"

# %%
LOCA_KEYS = [ 62, 63, 64, 76, 77, 78, 79, 90, 91, 92, 93, 94,
              104, 105, 106, 107, 108, 120, 121, 122, 123, 136, 137 ]
NUM_LOCA_GRID = len( LOCA_KEYS )

# %%
OurQList = [ round( 0.01 * x, 2 ) for x in range(100) ]
OurQList.append( 0.995 )
OurQList.append( 0.999 )
OurQList.append( 0.9999 )
OurQList.append( 1.0 )
OurQList[95:]
OurQs = np.array( OurQList, dtype=np.float32 )
NumQs = len( OurQs )
NumQs
# Out:
# 104

# %% [markdown]
# ### Jan

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Jan.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DJanDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Jan.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1JanDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Jan.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2JanDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Jan.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3JanDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DJanDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1JanDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2JanDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3JanDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Jan", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DJanDF
del H1P1JanDF
del H1P2JanDF
del H1P3JanDF

# %% [markdown]
# ### Feb

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Feb.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DFebDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Feb.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1FebDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Feb.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2FebDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Feb.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3FebDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DFebDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1FebDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2FebDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3FebDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Feb", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DFebDF
del H1P1FebDF
del H1P2FebDF
del H1P3FebDF

# %% [markdown]
# ### Mar

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Mar.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DMarDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Mar.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1MarDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Mar.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2MarDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Mar.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3MarDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DMarDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1MarDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2MarDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3MarDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Mar", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DMarDF
del H1P1MarDF
del H1P2MarDF
del H1P3MarDF

# %% [markdown]
# ### Apr

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Apr.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DAprDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Apr.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1AprDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Apr.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2AprDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Apr.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3AprDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DAprDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1AprDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2AprDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3AprDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Apr", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DAprDF
del H1P1AprDF
del H1P2AprDF
del H1P3AprDF

# %% [markdown]
# ### May

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_May.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DMayDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_May.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1MayDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_May.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2MayDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_May.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3MayDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DMayDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1MayDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2MayDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3MayDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG May", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DMayDF
del H1P1MayDF
del H1P2MayDF
del H1P3MayDF

# %% [markdown]
# ### Jun

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Jun.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DJunDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Jun.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1JunDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Jun.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2JunDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Jun.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3JunDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DJunDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1JunDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2JunDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3JunDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Jun", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DJunDF
del H1P1JunDF
del H1P2JunDF
del H1P3JunDF

# %% [markdown]
# ### Jul

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Jul.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DJulDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Jul.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1JulDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Jul.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2JulDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Jul.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3JulDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DJulDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1JulDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2JulDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3JulDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Jul", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DJulDF
del H1P1JulDF
del H1P2JulDF
del H1P3JulDF

# %% [markdown]
# ### Aug

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Aug.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DAugDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Aug.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1AugDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Aug.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2AugDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Aug.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3AugDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DAugDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1AugDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2AugDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3AugDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Aug", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DAugDF
del H1P1AugDF
del H1P2AugDF
del H1P3AugDF

# %% [markdown]
# ### Sep

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Sep.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DSepDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Sep.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1SepDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Sep.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2SepDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Sep.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3SepDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DSepDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1SepDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2SepDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3SepDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Sep", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DSepDF
del H1P1SepDF
del H1P2SepDF
del H1P3SepDF

# %% [markdown]
# ### Oct

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Oct.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DOctDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Oct.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1OctDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Oct.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2OctDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Oct.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3OctDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DOctDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1OctDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2OctDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3OctDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Oct", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DOctDF
del H1P1OctDF
del H1P2OctDF
del H1P3OctDF

# %% [markdown]
# ### Nov

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Nov.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DNovDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Nov.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1NovDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Nov.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2NovDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Nov.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3NovDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DNovDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1NovDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2NovDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3NovDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Nov", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DNovDF
del H1P1NovDF
del H1P2NovDF
del H1P3NovDF

# %% [markdown]
# ### Dec

# %%
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1DPDepth_Dec.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1DDecDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P1PDepth_Dec.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P1DecDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P2PDepth_Dec.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P2DecDF = pickle.load(InP)
# end of with
InPickle = os.path.normpath( os.path.join( OUT_DIR, 'H1P3PDepth_Dec.pickle' ) )
with open( InPickle, 'rb' ) as InP:
    H1P3DecDF = pickle.load(InP)
# end of with

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( H1DDecDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:light green', label='H1 Data')
ax11.plot( H1P1DecDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:neon green', label='H1 Proj 1')
ax11.plot( H1P2DecDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:grass green', label='H1 Proj 2')
ax11.plot( H1P3DecDF['PDepth_mm'].quantile(q=OurQs), OurQs, linestyle='-', linewidth=3,
           color='xkcd:forest green', label='H1 Proj 3')
ax11.set_xlim( (0.0, 100.0))
ax11.set_ylim( (0.0, 1.05) )
ax11.set_title("H1 WG Dec", fontsize=16)
ax11.set_xlabel('Wet Day Precipitation Depth (mm)', fontsize=14 )
ax11.set_ylabel('Cumulative Probability', fontsize=14)
ax11.grid( b=True )
ax11.legend(loc='lower right')
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )

# %%
del H1DDecDF
del H1P1DecDF
del H1P2DecDF
del H1P3DecDF
