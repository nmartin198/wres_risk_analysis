# %% [markdown]
# # Water Budget Results: Plot Delta Precipitation

# %% [markdown]
# Plot precipitation items from the water budget results

# %% [markdown]
# ## Parameters and Imports

# %%
# %matplotlib inline

# %%
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pickle
import seaborn as sns
from copy import deepcopy

# %%
IN_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Process_Results'
SIM_ROOT1 = "DC_WGMN1"
SIM_ROOT2 = "DC_WGMN2"
SIM_ROOT3 = "DC_WGMN3"
XLSX_ROOT = "%s_ProcessMonthly_Stats.xlsx"

# %%
OUT_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Events'

# %%
SM_NUM = 16

# %%
# time periods
TP_DICT = { 1 : [ dt.datetime(1981, 1, 1), dt.datetime(2010, 12, 31)],
            2 : [ dt.datetime(2011, 1, 1), dt.datetime(2040, 12, 31)],
            3 : [ dt.datetime(2041, 1, 1), dt.datetime(2070, 12, 31)],
            4 : [ dt.datetime(2071, 1, 1), dt.datetime(2100, 12, 31)],}

# %%
OurQs = np.array( [ round( 0.01 * x, 2 ) for x in range(101) ], dtype=np.float32 )
NumQs = len( OurQs )
NumQs
# Out:
# 101

# %%
StatsHdsList = list()
for iI in range(NumQs):
    cQ = OurQs[iI]
    Hdr = "%d_ptile" % round(cQ * 100.0)
    StatsHdsList.append( Hdr )
# end of for
StatsHdsList.append( "Average" )
StatsHdsList.append( "Variance" )
StatsHdsList.append( "Skew" )
StatsHdsList.append( "Kurt" )

# %%
NumHdrs = len( StatsHdsList )
NumHdrs
# Out:
# 105

# %%
RdHds = deepcopy( StatsHdsList )
RdHds.insert( 0, "Date" )

# %% [markdown]
# ## Load from Spreadsheets

# %% [markdown]
# ### Scenario 1

# %%
InFile1 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT1 ) )
S1PreStats1 = pd.read_excel( InFile1, sheet_name="Precip_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
display( HTML( S1PreStats1.head().to_html() ) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0_ptile</th>
#       <th>1_ptile</th>
#       <th>2_ptile</th>
#       <th>3_ptile</th>
#       <th>4_ptile</th>
#       <th>5_ptile</th>
#       <th>6_ptile</th>
#       <th>7_ptile</th>
#       <th>8_ptile</th>
#       <th>9_ptile</th>
#       <th>10_ptile</th>
#       <th>11_ptile</th>
#       <th>12_ptile</th>
#       <th>13_ptile</th>
#       <th>14_ptile</th>
#       <th>15_ptile</th>
#       <th>16_ptile</th>
#       <th>17_ptile</th>
#       <th>18_ptile</th>
#       <th>19_ptile</th>
#       <th>20_ptile</th>
#       <th>21_ptile</th>
#       <th>22_ptile</th>
#       <th>23_ptile</th>
#       <th>24_ptile</th>
#       <th>25_ptile</th>
#       <th>26_ptile</th>
#       <th>27_ptile</th>
#       <th>28_ptile</th>
#       <th>29_ptile</th>
#       <th>30_ptile</th>
#       <th>31_ptile</th>
#       <th>32_ptile</th>
#       <th>33_ptile</th>
# ...

# %%
S1MaxPrecip1 = S1PreStats1[StatsHdsList[100]].max()
S1MinPrecip1 = S1PreStats1[StatsHdsList[0]].min()
S1MaxPrecip1, S1MinPrecip1
# Out:
# (25.81151045153092, -26.23167913715588)

# %%
S1PreStats2 = pd.read_excel( InFile1, sheet_name="Precip_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxPrecip2 = S1PreStats2[StatsHdsList[100]].max()
S1MinPrecip2 = S1PreStats2[StatsHdsList[0]].min()
S1MaxPrecip2, S1MinPrecip2
# Out:
# (619.8285888062092, -467.3831875841133)

# %%
S1PreStats3 = pd.read_excel( InFile1, sheet_name="Precip_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxPrecip3 = S1PreStats3[StatsHdsList[100]].max()
S1MinPrecip3 = S1PreStats3[StatsHdsList[0]].min()
S1MaxPrecip3, S1MinPrecip3
# Out:
# (650.7072368552326, -507.2260869168385)

# %%
S1PreStats4 = pd.read_excel( InFile1, sheet_name="Precip_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxPrecip4 = S1PreStats4[StatsHdsList[100]].max()
S1MinPrecip4 = S1PreStats4[StatsHdsList[0]].min()
S1MaxPrecip4, S1MinPrecip4
# Out:
# (715.9877105632331, -615.3601665870956)

# %%
S1MaxPrecip = max( S1MaxPrecip1, S1MaxPrecip2, S1MaxPrecip3, S1MaxPrecip4 )
S1MinPrecip = min( S1MinPrecip1, S1MinPrecip2, S1MinPrecip3, S1MinPrecip4 )
S1MaxPrecip, S1MinPrecip
# Out:
# (715.9877105632331, -615.3601665870956)

# %% [markdown]
# ### Scenario 2

# %%
InFile2 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT2 ) )
S2PreStats1 = pd.read_excel( InFile2, sheet_name="Precip_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxPrecip1 = S2PreStats1[StatsHdsList[100]].max()
S2MinPrecip1 = S2PreStats1[StatsHdsList[0]].min()
S2MaxPrecip1, S2MinPrecip1
# Out:
# (25.81151045153092, -26.23167913715588)

# %%
S2PreStats2 = pd.read_excel( InFile2, sheet_name="Precip_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxPrecip2 = S2PreStats2[StatsHdsList[100]].max()
S2MinPrecip2 = S2PreStats2[StatsHdsList[0]].min()
S2MaxPrecip2, S2MinPrecip2
# Out:
# (696.5999445063062, -467.3801961085992)

# %%
S2PreStats3 = pd.read_excel( InFile2, sheet_name="Precip_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxPrecip3 = S2PreStats3[StatsHdsList[100]].max()
S2MinPrecip3 = S2PreStats3[StatsHdsList[0]].min()
S2MaxPrecip3, S2MinPrecip3
# Out:
# (750.7543292854389, -507.2034340823011)

# %%
S2PreStats4 = pd.read_excel( InFile2, sheet_name="Precip_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxPrecip4 = S2PreStats4[StatsHdsList[100]].max()
S2MinPrecip4 = S2PreStats4[StatsHdsList[0]].min()
S2MaxPrecip4, S2MinPrecip4
# Out:
# (877.8430193448439, -615.3590138373402)

# %%
S2MaxPrecip = max( S2MaxPrecip1, S2MaxPrecip2, S2MaxPrecip3, S2MaxPrecip4 )
S2MinPrecip = min( S2MinPrecip1, S2MinPrecip2, S2MinPrecip3, S2MinPrecip4 )
S2MaxPrecip, S2MinPrecip
# Out:
# (877.8430193448439, -615.3590138373402)

# %% [markdown]
# ### Scenario 3

# %%
InFile3 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT3 ) )
S3PreStats1 = pd.read_excel( InFile3, sheet_name="Precip_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxPrecip1 = S3PreStats1[StatsHdsList[100]].max()
S3MinPrecip1 = S3PreStats1[StatsHdsList[0]].min()
S3MaxPrecip1, S3MinPrecip1
# Out:
# (0, 0)

# %%
S3PreStats2 = pd.read_excel( InFile3, sheet_name="Precip_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxPrecip2 = S3PreStats2[StatsHdsList[100]].max()
S3MinPrecip2 = S3PreStats2[StatsHdsList[0]].min()
S3MaxPrecip2, S3MinPrecip2
# Out:
# (124.0727710491337, -51.30391935165972)

# %%
S3PreStats3 = pd.read_excel( InFile3, sheet_name="Precip_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxPrecip3 = S3PreStats3[StatsHdsList[100]].max()
S3MinPrecip3 = S3PreStats3[StatsHdsList[0]].min()
S3MaxPrecip3, S3MinPrecip3
# Out:
# (129.0354790986166, -48.16621090914123)

# %%
S3PreStats4 = pd.read_excel( InFile3, sheet_name="Precip_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxPrecip4 = S3PreStats4[StatsHdsList[100]].max()
S3MinPrecip4 = S3PreStats4[StatsHdsList[0]].min()
S3MaxPrecip4, S3MinPrecip4
# Out:
# (163.4806172866956, -45.99279313249281)

# %%
S3MaxPrecip = max( S3MaxPrecip1, S3MaxPrecip2, S3MaxPrecip3, S3MaxPrecip4 )
S3MinPrecip = min( S3MinPrecip1, S3MinPrecip2, S3MinPrecip3, S3MinPrecip4 )
S3MaxPrecip, S3MinPrecip
# Out:
# (163.4806172866956, -51.30391935165972)

# %% [markdown]
# ## Plots

# %%
MaxPrecip = max( S1MaxPrecip, S2MaxPrecip, S3MaxPrecip )
MinPrecip = min( S1MinPrecip, S2MinPrecip, S3MinPrecip )
MaxPrecip, MinPrecip
# Out:
# (877.8430193448439, -615.3601665870956)

# %%
MaxPrecip = 900.0
MinPrecip = -700.0

# %% [markdown]
# Individual Plots

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S1MinPrecip, S1MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S1MinPrecip, S1MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S1MinPrecip, S1MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S1PreStats1.index, S1PreStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S1PreStats2.index, S1PreStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PreStats3.index, S1PreStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PreStats4.index, S1PreStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PreStats1.index, S1PreStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S1PreStats2.index, S1PreStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PreStats3.index, S1PreStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PreStats4.index, S1PreStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PreStats1.index, S1PreStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S1PreStats2.index, S1PreStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PreStats3.index, S1PreStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PreStats4.index, S1PreStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PreStats1.index, S1PreStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S1PreStats2.index, S1PreStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S1PreStats3.index, S1PreStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S1PreStats4.index, S1PreStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
#ax11.set_ylim( (MinPrecip, MaxPrecip) )
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT1, fontsize=16)
#ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Probabilistic Difference in Precipitation (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S2MinPrecip, S2MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S2MinPrecip, S2MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S2MinPrecip, S2MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
#ax11.set_ylim( (MinPrecip, MaxPrecip) )
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT2, fontsize=16)
#ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Probabilistic Difference in Precipitation (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S3MinPrecip, S3MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S3MinPrecip, S3MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S3MinPrecip, S3MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S3PreStats1.index, S3PreStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S3PreStats2.index, S3PreStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3PreStats3.index, S3PreStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3PreStats4.index, S3PreStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3PreStats1.index, S3PreStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S3PreStats2.index, S3PreStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3PreStats3.index, S3PreStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3PreStats4.index, S3PreStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3PreStats1.index, S3PreStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S3PreStats2.index, S3PreStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3PreStats3.index, S3PreStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3PreStats4.index, S3PreStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3PreStats1.index, S3PreStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S3PreStats2.index, S3PreStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S3PreStats3.index, S3PreStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S3PreStats4.index, S3PreStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
#ax11.set_ylim( (MinPrecip, MaxPrecip) )
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT3, fontsize=16)
#ax11.set_xlabel('Day of the Year', fontsize=14 )
ax11.set_ylabel('Probabilistic Difference in Precipitation (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %% [markdown]
# All together now

# %%
MaxPrecip = 400.0
MinPrecip = -400.0

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_ScenPrecipDeltaPTH.svg" ) )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_ScenPrecipDeltaPTH.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_ScenPrecipDeltaPTH.png" ) )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_ScenPrecipDeltaPTH.png'

# %%
preTicks = [ -400.0, -200.0, -100.0, -50.0, 0.0, 50.0, 100.0, 200.0, 400.0 ]
s3Ticks = [ -100.0, -50.0, -25.0, -10.0, 0.0, 10.0, 25.0, 50.0, 100.0 ]

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(15, 21)
ax11 = Fig1.add_subplot(3,1,1)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S1PreStats1.index, S1PreStats1[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='95th percentile')
ax11.plot( S1PreStats2.index, S1PreStats2[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PreStats3.index, S1PreStats3[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PreStats4.index, S1PreStats4[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PreStats1.index, S1PreStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S1PreStats2.index, S1PreStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PreStats3.index, S1PreStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PreStats4.index, S1PreStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PreStats1.index, S1PreStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax11.plot( S1PreStats2.index, S1PreStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PreStats3.index, S1PreStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PreStats4.index, S1PreStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PreStats1.index, S1PreStats1[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='5th percentile' )
ax11.plot( S1PreStats2.index, S1PreStats2[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.plot( S1PreStats3.index, S1PreStats3[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.plot( S1PreStats4.index, S1PreStats4[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.set_yticks( preTicks )
ax11.set_ylim( (MinPrecip, MaxPrecip) )
ax11.grid(True, axis='y', which='both')
ax11.set_ylabel('Precipitation $\Delta$ ($mm$)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower center', fontsize=11.0)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax11.annotate("A: Scenario 1", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax11.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21 = Fig1.add_subplot(3,1,2)
ax21.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='95th percentile')
ax21.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax21.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax21.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='5th percentile' )
ax21.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax21.set_yticks( preTicks )
ax21.set_ylim( (MinPrecip, MaxPrecip) )
ax21.grid(True, axis='y', which='both')
ax21.set_ylabel('Precipitation $\Delta$ ($mm$)', fontsize=14)
ax21.grid( b=True )
ax21.legend( loc='lower center', fontsize=11.0)
ax21.tick_params(axis='both', which='major', labelsize=13)
ax21.tick_params(axis='x', which='major', labelrotation=30.0)
ax21.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax21.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax21.annotate("B: Scenario 2", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax21.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31 = Fig1.add_subplot(3,1,3)
ax31.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( S3PreStats1.index, S3PreStats1[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='95th percentile')
ax31.plot( S3PreStats2.index, S3PreStats2[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3PreStats3.index, S3PreStats3[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3PreStats4.index, S3PreStats4[StatsHdsList[95]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3PreStats1.index, S3PreStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax31.plot( S3PreStats2.index, S3PreStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3PreStats3.index, S3PreStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3PreStats4.index, S3PreStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3PreStats1.index, S3PreStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax31.plot( S3PreStats2.index, S3PreStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3PreStats3.index, S3PreStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3PreStats4.index, S3PreStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3PreStats1.index, S3PreStats1[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='5th percentile' )
ax31.plot( S3PreStats2.index, S3PreStats2[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.plot( S3PreStats3.index, S3PreStats3[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.plot( S3PreStats4.index, S3PreStats4[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
#ax31.set_ylim( (MinPrecip, MaxPrecip) )
ax31.set_yticks( s3Ticks )
ax31.set_ylim( (-100.0, 100.0) )
ax31.grid(True, axis='y', which='both')
ax31.set_ylabel('Precipitation $\Delta$ ($mm$)', fontsize=14)
ax31.grid( b=True )
ax31.legend( loc='lower center', fontsize=11.0 )
ax31.tick_params(axis='both', which='major', labelsize=13)
ax31.tick_params(axis='x', which='major', labelrotation=30.0)
ax31.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax31.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax31.annotate("C: Scenario 3", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax31.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "FF_PreDelta_Sc2.svg" ) )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\FF_PreDelta_Sc2.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "FF_PreDelta_Sc2.png" ) )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\FF_PreDelta_Sc2.png'

# %%
preTicks = [ -200.0, -100.0, -50.0, 0.0, 50.0, 100.0, 200.0, 300.0 ]

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax21 = Fig1.add_subplot(1,1,1)
ax21.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7 )
ax21.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7 )
ax21.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7 )
ax21.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[95]], linestyle='dotted',
           linewidth=1, color='xkcd:gunmetal', label='95th percentile')
ax21.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[95]], linestyle='dotted',
           linewidth=1, color='xkcd:gunmetal' )
ax21.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[95]], linestyle='dotted',
           linewidth=1, color='xkcd:gunmetal' )
ax21.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[95]], linestyle='dotted',
           linewidth=1, color='xkcd:gunmetal' )
ax21.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:medium grey', label='Mean' )
ax21.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:medium grey' )
ax21.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:medium grey' )
ax21.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:medium grey' )
ax21.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[50]], linestyle='-',
           linewidth=1.5, color='xkcd:silver', label='Median, 50th percentile')
ax21.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[50]], linestyle='-',
           linewidth=1.5, color='xkcd:silver' )
ax21.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[50]], linestyle='-',
           linewidth=1.5, color='xkcd:silver' )
ax21.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[50]], linestyle='-',
           linewidth=1.5, color='xkcd:silver' )
ax21.plot( S2PreStats1.index, S2PreStats1[StatsHdsList[5]], linestyle='dashed',
           linewidth=1, color='xkcd:battleship grey', label='5th percentile' )
ax21.plot( S2PreStats2.index, S2PreStats2[StatsHdsList[5]], linestyle='dashed',
           linewidth=1, color='xkcd:battleship grey' )
ax21.plot( S2PreStats3.index, S2PreStats3[StatsHdsList[5]], linestyle='dashed',
           linewidth=1, color='xkcd:battleship grey' )
ax21.plot( S2PreStats4.index, S2PreStats4[StatsHdsList[5]], linestyle='dashed',
           linewidth=1, color='xkcd:battleship grey' )
ax21.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax21.set_yticks( preTicks )
ax21.set_ylim( (-200.0, 300.0) )
ax21.grid(True, axis='y', which='both')
ax21.set_ylabel('Precipitation $\Delta$ ($mm$)', fontsize=14)
ax21.grid( b=True )
ax21.legend( loc='lower center', ncol=2, fontsize=11.0)
ax21.tick_params(axis='both', which='major', labelsize=13)
ax21.tick_params(axis='x', which='major', labelrotation=30.0)
ax21.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax21.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax21.annotate("Projection Interval 1", xy=(0.06, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 2", xy=(0.40, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 3", xy=(0.72, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )

# %% [markdown]
# Fourier smoothing

# %%
rft = np.fft.rfft( S2PreStats1[StatsHdsList[95]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre1_95 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats2[StatsHdsList[95]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre2_95 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats3[StatsHdsList[95]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre3_95 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats4[StatsHdsList[95]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre4_95 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats1[StatsHdsList[5]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre1_5 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats2[StatsHdsList[5]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre2_5 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats3[StatsHdsList[5]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre3_5 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats4[StatsHdsList[5]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre4_5 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats1[StatsHdsList[50]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre1_50 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats2[StatsHdsList[50]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre2_50 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats3[StatsHdsList[50]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre3_50 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats4[StatsHdsList[50]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre4_50 = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats1[StatsHdsList[101]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre1_me = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats2[StatsHdsList[101]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre2_me = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats3[StatsHdsList[101]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre3_me = np.fft.irfft(rft)
rft = np.fft.rfft( S2PreStats4[StatsHdsList[101]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_Pre4_me = np.fft.irfft(rft)

# %%
DTTL_2 = list( S2PreStats2.index.to_pydatetime() )
DTTL_3 = list( S2PreStats3.index.to_pydatetime() )
DTTL_4 = list( S2PreStats4.index.to_pydatetime() )
BackDTList = deepcopy( DTTL_2 )
BackDTTL_2 = BackDTList[::-1]
BackDTList = deepcopy( DTTL_3 )
BackDTTL_3 = BackDTList[::-1]
BackDTList = deepcopy( DTTL_4 )
BackDTTL_4 = BackDTList[::-1]
DTTimeList = deepcopy( DTTL_2 )
DTTimeList.extend( DTTL_3 )
DTTimeList.extend( DTTL_4 )
DTTimeList.extend( BackDTTL_4 )
DTTimeList.extend( BackDTTL_3 )
DTTimeList.extend( BackDTTL_2 )

# %%
Pre2_5 = list( FF_Pre2_5 )
Pre3_5 = list( FF_Pre3_5 )
Pre4_5 = list( FF_Pre4_5 )
BackDTList = list( FF_Pre4_95 )
BackPre4_95 = BackDTList[::-1]
BackDTList = list( FF_Pre3_95 )
BackPre3_95 = BackDTList[::-1]
BackDTList = list( FF_Pre2_95 )
BackPre2_95 = BackDTList[::-1]
PreVals = deepcopy( Pre2_5 )
PreVals.extend( Pre3_5 )
PreVals.extend( Pre4_5 )
PreVals.extend( BackPre4_95 )
PreVals.extend( BackPre3_95 )
PreVals.extend( BackPre2_95 )

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "FF_PreDelta_Sc2FSm.svg" ) )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\FF_PreDelta_Sc2FSm.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "FF_PreDelta_Sc2FSm.png" ) )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\FF_PreDelta_Sc2FSm.png'

# %%
MaxPrecip = 200.0
MinPrecip = -125.0

# %%
preTicks = [ -100.0, -50.0, 0.0, 50.0, 100.0, 150.0 ]

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(12.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7)
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7 )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinPrecip, MaxPrecip], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7 )
sfF = ax11.fill( DTTimeList, PreVals, color='xkcd:medium grey', alpha=0.40, 
                 label="5th to 95th percentile range")
ax11.plot( S2PreStats2.index, FF_Pre2_me, linestyle='-',
           linewidth=3, color='xkcd:gunmetal', label='Mean' )
ax11.plot( S2PreStats3.index, FF_Pre3_me, linestyle='-',
           linewidth=3, color='xkcd:gunmetal' )
ax11.plot( S2PreStats4.index, FF_Pre4_me, linestyle='-',
           linewidth=3, color='xkcd:gunmetal' )
ax11.plot( S2PreStats2.index, FF_Pre2_50, linestyle='dashed',
           linewidth=3, color='xkcd:pale grey', label='Median' )
ax11.plot( S2PreStats3.index, FF_Pre3_50, linestyle='dashed',
           linewidth=3, color='xkcd:pale grey' )
ax11.plot( S2PreStats4.index, FF_Pre4_50, linestyle='dashed',
           linewidth=3, color='xkcd:pale grey' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.set_yticks( preTicks )
ax11.set_ylim( (MinPrecip, MaxPrecip) )
ax11.grid(True, axis='y', which='both')
ax11.set_ylabel('Precipitation $\Delta$ ($mm$)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower center', ncol=3, fontsize=12.0, facecolor="xkcd:light grey")
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=15.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax11.annotate("Projection Interval 1", xy=(0.09, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 2", xy=(0.42, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 3", xy=(0.75, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )
