# %% [markdown]
# # Water Budget Results: Plot Delta AET

# %% [markdown]
# Plot AET items from the water budget results

# %% [markdown]
# ## Parameters and Imports

# %%
# %matplotlib inline

# %%
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pickle
import seaborn as sns
from copy import deepcopy

# %%
IN_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Process_Results'
SIM_ROOT1 = "DC_WGMN1"
SIM_ROOT2 = "DC_WGMN2"
SIM_ROOT3 = "DC_WGMN3"
XLSX_ROOT = "%s_ProcessMonthly_Stats.xlsx"

# %%
OUT_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Events'

# %%
# time periods
TP_DICT = { 1 : [ dt.datetime(1981, 1, 1), dt.datetime(2010, 12, 31)],
            2 : [ dt.datetime(2011, 1, 1), dt.datetime(2040, 12, 31)],
            3 : [ dt.datetime(2041, 1, 1), dt.datetime(2070, 12, 31)],
            4 : [ dt.datetime(2071, 1, 1), dt.datetime(2100, 12, 31)],}

# %%
OurQs = np.array( [ round( 0.01 * x, 2 ) for x in range(101) ], dtype=np.float32 )
NumQs = len( OurQs )
NumQs
# Out:
# 101

# %%
StatsHdsList = list()
for iI in range(NumQs):
    cQ = OurQs[iI]
    Hdr = "%d_ptile" % round(cQ * 100.0)
    StatsHdsList.append( Hdr )
# end of for
StatsHdsList.append( "Average" )
StatsHdsList.append( "Variance" )
StatsHdsList.append( "Skew" )
StatsHdsList.append( "Kurt" )

# %%
NumHdrs = len( StatsHdsList )
NumHdrs
# Out:
# 105

# %%
RdHds = deepcopy( StatsHdsList )
RdHds.insert( 0, "Date" )

# %% [markdown]
# ## Load from Spreadsheets

# %% [markdown]
# ### Scenario 1

# %%
InFile1 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT1 ) )
S1AETStats1 = pd.read_excel( InFile1, sheet_name="AET_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
display( HTML( S1AETStats1.head().to_html() ) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0_ptile</th>
#       <th>1_ptile</th>
#       <th>2_ptile</th>
#       <th>3_ptile</th>
#       <th>4_ptile</th>
#       <th>5_ptile</th>
#       <th>6_ptile</th>
#       <th>7_ptile</th>
#       <th>8_ptile</th>
#       <th>9_ptile</th>
#       <th>10_ptile</th>
#       <th>11_ptile</th>
#       <th>12_ptile</th>
#       <th>13_ptile</th>
#       <th>14_ptile</th>
#       <th>15_ptile</th>
#       <th>16_ptile</th>
#       <th>17_ptile</th>
#       <th>18_ptile</th>
#       <th>19_ptile</th>
#       <th>20_ptile</th>
#       <th>21_ptile</th>
#       <th>22_ptile</th>
#       <th>23_ptile</th>
#       <th>24_ptile</th>
#       <th>25_ptile</th>
#       <th>26_ptile</th>
#       <th>27_ptile</th>
#       <th>28_ptile</th>
#       <th>29_ptile</th>
#       <th>30_ptile</th>
#       <th>31_ptile</th>
#       <th>32_ptile</th>
#       <th>33_ptile</th>
# ...

# %%
S1MaxAET1 = S1AETStats1[StatsHdsList[100]].max()
S1MinAET1 = S1AETStats1[StatsHdsList[0]].min()
S1MaxAET1, S1MinAET1
# Out:
# (24.53970962687988, -26.64304545537322)

# %%
S1AETStats2 = pd.read_excel( InFile1, sheet_name="AET_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxAET2 = S1AETStats2[StatsHdsList[100]].max()
S1MinAET2 = S1AETStats2[StatsHdsList[0]].min()
S1MaxAET2, S1MinAET2
# Out:
# (169.2628279655153, -161.0680909389504)

# %%
S1AETStats3 = pd.read_excel( InFile1, sheet_name="AET_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxAET3 = S1AETStats3[StatsHdsList[100]].max()
S1MinAET3 = S1AETStats3[StatsHdsList[0]].min()
S1MaxAET3, S1MinAET3
# Out:
# (178.800625743386, -157.0889409813568)

# %%
S1AETStats4 = pd.read_excel( InFile1, sheet_name="AET_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxAET4 = S1AETStats4[StatsHdsList[100]].max()
S1MinAET4 = S1AETStats4[StatsHdsList[0]].min()
S1MaxAET4, S1MinAET4
# Out:
# (183.6848784635043, -160.4298788781556)

# %%
S1MaxAET = max( S1MaxAET1, S1MaxAET2, S1MaxAET3, S1MaxAET4 )
S1MinAET = min( S1MinAET1, S1MinAET2, S1MinAET3, S1MinAET4 )
S1MaxAET, S1MinAET
# Out:
# (183.6848784635043, -161.0680909389504)

# %% [markdown]
# ### Scenario 2

# %%
InFile2 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT2 ) )
S2AETStats1 = pd.read_excel( InFile2, sheet_name="AET_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxAET1 = S2AETStats1[StatsHdsList[100]].max()
S2MinAET1 = S2AETStats1[StatsHdsList[0]].min()
S2MaxAET1, S2MinAET1
# Out:
# (24.53970962687988, -26.64304545537322)

# %%
S2AETStats2 = pd.read_excel( InFile2, sheet_name="AET_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxAET2 = S2AETStats2[StatsHdsList[100]].max()
S2MinAET2 = S2AETStats2[StatsHdsList[0]].min()
S2MaxAET2, S2MinAET2
# Out:
# (169.2628279655153, -159.9925148080935)

# %%
S2AETStats3 = pd.read_excel( InFile2, sheet_name="AET_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxAET3 = S2AETStats3[StatsHdsList[100]].max()
S2MinAET3 = S2AETStats3[StatsHdsList[0]].min()
S2MaxAET3, S2MinAET3
# Out:
# (179.5086920455795, -157.0881941691305)

# %%
S2AETStats4 = pd.read_excel( InFile2, sheet_name="AET_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxAET4 = S2AETStats4[StatsHdsList[100]].max()
S2MinAET4 = S2AETStats4[StatsHdsList[0]].min()
S2MaxAET4, S2MinAET4
# Out:
# (188.8736611212542, -160.4296932011801)

# %%
S2MaxAET = max( S2MaxAET1, S2MaxAET2, S2MaxAET3, S2MaxAET4 )
S2MinAET = min( S2MinAET1, S2MinAET2, S2MinAET3, S2MinAET4 )
S2MaxAET, S2MinAET
# Out:
# (188.8736611212542, -160.4296932011801)

# %% [markdown]
# ### Scenario 3

# %%
InFile3 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT3 ) )
S3AETStats1 = pd.read_excel( InFile3, sheet_name="AET_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxAET1 = S3AETStats1[StatsHdsList[100]].max()
S3MinAET1 = S3AETStats1[StatsHdsList[0]].min()
S3MaxAET1, S3MinAET1
# Out:
# (0, 0)

# %%
S3AETStats2 = pd.read_excel( InFile3, sheet_name="AET_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxAET2 = S3AETStats2[StatsHdsList[100]].max()
S3MinAET2 = S3AETStats2[StatsHdsList[0]].min()
S3MaxAET2, S3MinAET2
# Out:
# (54.07443534943741, -40.83842603692881)

# %%
S3AETStats3 = pd.read_excel( InFile3, sheet_name="AET_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxAET3 = S3AETStats3[StatsHdsList[100]].max()
S3MinAET3 = S3AETStats3[StatsHdsList[0]].min()
S3MaxAET3, S3MinAET3
# Out:
# (63.46012358663459, -41.90353518287208)

# %%
S3AETStats4 = pd.read_excel( InFile3, sheet_name="AET_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxAET4 = S3AETStats4[StatsHdsList[100]].max()
S3MinAET4 = S3AETStats4[StatsHdsList[0]].min()
S3MaxAET4, S3MinAET4
# Out:
# (68.15944987630428, -41.36181741095376)

# %%
S3MaxAET = max( S3MaxAET1, S3MaxAET2, S3MaxAET3, S3MaxAET4 )
S3MinAET = min( S3MinAET1, S3MinAET2, S3MinAET3, S3MinAET4 )
S3MaxAET, S3MinAET
# Out:
# (68.15944987630428, -41.90353518287208)

# %% [markdown]
# ## Plots

# %%
MaxAET = max( S1MaxAET, S2MaxAET, S3MaxAET )
MinAET = min( S1MinAET, S2MinAET, S3MinAET )
MaxAET, MinAET
# Out:
# (188.8736611212542, -161.0680909389504)

# %%
MaxAET = 200.0
MinAET = -200.0

# %% [markdown]
# Individual Plots

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S1MinAET, S1MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S1MinAET, S1MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S1MinAET, S1MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S1AETStats1.index, S1AETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S1AETStats2.index, S1AETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1AETStats3.index, S1AETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1AETStats4.index, S1AETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1AETStats1.index, S1AETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S1AETStats2.index, S1AETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1AETStats3.index, S1AETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1AETStats4.index, S1AETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1AETStats1.index, S1AETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S1AETStats2.index, S1AETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1AETStats3.index, S1AETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1AETStats4.index, S1AETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1AETStats1.index, S1AETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S1AETStats2.index, S1AETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S1AETStats3.index, S1AETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S1AETStats4.index, S1AETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT1, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in AET (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S2MinAET, S2MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S2MinAET, S2MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S2MinAET, S2MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S2AETStats1.index, S2AETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S2AETStats2.index, S2AETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2AETStats3.index, S2AETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2AETStats4.index, S2AETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2AETStats1.index, S2AETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S2AETStats2.index, S2AETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2AETStats3.index, S2AETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2AETStats4.index, S2AETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2AETStats1.index, S2AETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S2AETStats2.index, S2AETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2AETStats3.index, S2AETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2AETStats4.index, S2AETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2AETStats1.index, S2AETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S2AETStats2.index, S2AETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S2AETStats3.index, S2AETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S2AETStats4.index, S2AETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT2, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in AET (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S3MinAET, S3MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S3MinAET, S3MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S3MinAET, S3MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S3AETStats1.index, S3AETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S3AETStats2.index, S3AETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3AETStats3.index, S3AETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3AETStats4.index, S3AETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3AETStats1.index, S3AETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S3AETStats2.index, S3AETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3AETStats3.index, S3AETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3AETStats4.index, S3AETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3AETStats1.index, S3AETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S3AETStats2.index, S3AETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3AETStats3.index, S3AETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3AETStats4.index, S3AETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3AETStats1.index, S3AETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S3AETStats2.index, S3AETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S3AETStats3.index, S3AETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S3AETStats4.index, S3AETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT3, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in AET (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %% [markdown]
# All together now

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_ScenAETDeltaPTH.svg" ) )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_ScenAETDeltaPTH.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_ScenAETDeltaPTH.png" ) )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_ScenAETDeltaPTH.png'

# %%
MaxAET = 250.0
MinAET = -250.0

# %%
aetTicks = [ -200.0, -100.0, -50.0, -25.0, 0.0, 25.0, 50.0, 100.0, 200.0 ]

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(15, 21)
ax11 = Fig1.add_subplot(3,1,1)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinAET, MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinAET, MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinAET, MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S1AETStats1.index, S1AETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax11.plot( S1AETStats2.index, S1AETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1AETStats3.index, S1AETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1AETStats4.index, S1AETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1AETStats1.index, S1AETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S1AETStats2.index, S1AETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1AETStats3.index, S1AETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1AETStats4.index, S1AETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1AETStats1.index, S1AETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax11.plot( S1AETStats2.index, S1AETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1AETStats3.index, S1AETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1AETStats4.index, S1AETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1AETStats1.index, S1AETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax11.plot( S1AETStats2.index, S1AETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.plot( S1AETStats3.index, S1AETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.plot( S1AETStats4.index, S1AETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.set_yticks( aetTicks )
ax11.set_ylim( (MinAET, MaxAET) )
ax11.grid(True, axis='y', which='both')
ax11.set_ylabel('Probabilistic Difference in AET (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower center', fontsize=11.0)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax11.annotate("A: Scenario 1", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax11.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21 = Fig1.add_subplot(3,1,2)
ax21.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinAET, MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinAET, MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinAET, MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( S2AETStats1.index, S2AETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax21.plot( S2AETStats2.index, S2AETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2AETStats3.index, S2AETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2AETStats4.index, S2AETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2AETStats1.index, S2AETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax21.plot( S2AETStats2.index, S2AETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2AETStats3.index, S2AETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2AETStats4.index, S2AETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2AETStats1.index, S2AETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax21.plot( S2AETStats2.index, S2AETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2AETStats3.index, S2AETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2AETStats4.index, S2AETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2AETStats1.index, S2AETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax21.plot( S2AETStats2.index, S2AETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.plot( S2AETStats3.index, S2AETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.plot( S2AETStats4.index, S2AETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax21.set_yticks( aetTicks )
ax21.set_ylim( (MinAET, MaxAET) )
ax21.grid(True, axis='y', which='both')
ax21.set_ylabel('Probabilistic Difference in AET (mm)', fontsize=14)
ax21.grid( b=True )
ax21.legend( loc='lower center', fontsize=11.0 )
ax21.tick_params(axis='both', which='major', labelsize=13)
ax21.tick_params(axis='x', which='major', labelrotation=30.0)
ax21.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax21.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax21.annotate("B: Scenario 2", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax21.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31 = Fig1.add_subplot(3,1,3)
ax31.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinAET, MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinAET, MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinAET, MaxAET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( S3AETStats1.index, S3AETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax31.plot( S3AETStats2.index, S3AETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3AETStats3.index, S3AETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3AETStats4.index, S3AETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3AETStats1.index, S3AETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax31.plot( S3AETStats2.index, S3AETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3AETStats3.index, S3AETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3AETStats4.index, S3AETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3AETStats1.index, S3AETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax31.plot( S3AETStats2.index, S3AETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3AETStats3.index, S3AETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3AETStats4.index, S3AETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3AETStats1.index, S3AETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax31.plot( S3AETStats2.index, S3AETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.plot( S3AETStats3.index, S3AETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.plot( S3AETStats4.index, S3AETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
#ax31.set_ylim( (MinAET, MaxAET) )
ax31.set_yticks( aetTicks )
ax31.set_ylim( (-100.0, 100.0) )
ax31.grid(True, axis='y', which='both')
ax31.set_ylabel('Probabilistic Difference in AET (mm)', fontsize=14)
ax31.grid( b=True )
ax31.legend( loc='lower center', fontsize=11.0 )
ax31.tick_params(axis='both', which='major', labelsize=13)
ax31.tick_params(axis='x', which='major', labelrotation=30.0)
ax31.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax31.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax31.annotate("C: Scenario 3", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax31.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )
