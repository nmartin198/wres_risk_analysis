# %% [markdown]
# # Water Budget Results: Plot Delta PET

# %% [markdown]
# Plot PET items from the water budget results

# %% [markdown]
# ## Parameters and Imports

# %%
# %matplotlib inline

# %%
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pickle
import seaborn as sns
from copy import deepcopy

# %%
IN_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Process_Results'
SIM_ROOT1 = "DC_WGMN1"
SIM_ROOT2 = "DC_WGMN2"
SIM_ROOT3 = "DC_WGMN3"
XLSX_ROOT = "%s_ProcessMonthly_Stats.xlsx"

# %%
OUT_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Events'

# %%
# time periods
TP_DICT = { 1 : [ dt.datetime(1981, 1, 1), dt.datetime(2010, 12, 31)],
            2 : [ dt.datetime(2011, 1, 1), dt.datetime(2040, 12, 31)],
            3 : [ dt.datetime(2041, 1, 1), dt.datetime(2070, 12, 31)],
            4 : [ dt.datetime(2071, 1, 1), dt.datetime(2100, 12, 31)],}

# %%
OurQs = np.array( [ round( 0.01 * x, 2 ) for x in range(101) ], dtype=np.float32 )
NumQs = len( OurQs )
NumQs
# Out:
# 101

# %%
StatsHdsList = list()
for iI in range(NumQs):
    cQ = OurQs[iI]
    Hdr = "%d_ptile" % round(cQ * 100.0)
    StatsHdsList.append( Hdr )
# end of for
StatsHdsList.append( "Average" )
StatsHdsList.append( "Variance" )
StatsHdsList.append( "Skew" )
StatsHdsList.append( "Kurt" )

# %%
NumHdrs = len( StatsHdsList )
NumHdrs
# Out:
# 105

# %%
RdHds = deepcopy( StatsHdsList )
RdHds.insert( 0, "Date" )

# %% [markdown]
# ## Load from Spreadsheets

# %% [markdown]
# ### Scenario 1

# %%
InFile1 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT1 ) )
S1PETStats1 = pd.read_excel( InFile1, sheet_name="PET_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
display( HTML( S1PETStats1.head().to_html() ) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0_ptile</th>
#       <th>1_ptile</th>
#       <th>2_ptile</th>
#       <th>3_ptile</th>
#       <th>4_ptile</th>
#       <th>5_ptile</th>
#       <th>6_ptile</th>
#       <th>7_ptile</th>
#       <th>8_ptile</th>
#       <th>9_ptile</th>
#       <th>10_ptile</th>
#       <th>11_ptile</th>
#       <th>12_ptile</th>
#       <th>13_ptile</th>
#       <th>14_ptile</th>
#       <th>15_ptile</th>
#       <th>16_ptile</th>
#       <th>17_ptile</th>
#       <th>18_ptile</th>
#       <th>19_ptile</th>
#       <th>20_ptile</th>
#       <th>21_ptile</th>
#       <th>22_ptile</th>
#       <th>23_ptile</th>
#       <th>24_ptile</th>
#       <th>25_ptile</th>
#       <th>26_ptile</th>
#       <th>27_ptile</th>
#       <th>28_ptile</th>
#       <th>29_ptile</th>
#       <th>30_ptile</th>
#       <th>31_ptile</th>
#       <th>32_ptile</th>
#       <th>33_ptile</th>
# ...

# %%
S1MaxPET1 = S1PETStats1[StatsHdsList[100]].max()
S1MinPET1 = S1PETStats1[StatsHdsList[0]].min()
S1MaxPET1, S1MinPET1
# Out:
# (10.17694704649227, -10.22802444209447)

# %%
S1PETStats2 = pd.read_excel( InFile1, sheet_name="PET_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxPET2 = S1PETStats2[StatsHdsList[100]].max()
S1MinPET2 = S1PETStats2[StatsHdsList[0]].min()
S1MaxPET2, S1MinPET2
# Out:
# (105.773529009508, -102.3387309794726)

# %%
S1PETStats3 = pd.read_excel( InFile1, sheet_name="PET_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxPET3 = S1PETStats3[StatsHdsList[100]].max()
S1MinPET3 = S1PETStats3[StatsHdsList[0]].min()
S1MaxPET3, S1MinPET3
# Out:
# (104.8058529360985, -103.6275386296342)

# %%
S1PETStats4 = pd.read_excel( InFile1, sheet_name="PET_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxPET4 = S1PETStats4[StatsHdsList[100]].max()
S1MinPET4 = S1PETStats4[StatsHdsList[0]].min()
S1MaxPET4, S1MinPET4
# Out:
# (120.786982515631, -106.661161662648)

# %%
S1MaxPET = max( S1MaxPET1, S1MaxPET2, S1MaxPET3, S1MaxPET4 )
S1MinPET = min( S1MinPET1, S1MinPET2, S1MinPET3, S1MinPET4 )
S1MaxPET, S1MinPET
# Out:
# (120.786982515631, -106.661161662648)

# %% [markdown]
# ### Scenario 2

# %%
InFile2 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT2 ) )
S2PETStats1 = pd.read_excel( InFile2, sheet_name="PET_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxPET1 = S2PETStats1[StatsHdsList[100]].max()
S2MinPET1 = S2PETStats1[StatsHdsList[0]].min()
S2MaxPET1, S2MinPET1
# Out:
# (10.17694704649227, -10.22802444209447)

# %%
S2PETStats2 = pd.read_excel( InFile2, sheet_name="PET_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxPET2 = S2PETStats2[StatsHdsList[100]].max()
S2MinPET2 = S2PETStats2[StatsHdsList[0]].min()
S2MaxPET2, S2MinPET2
# Out:
# (105.773529009508, -102.3387309794726)

# %%
S2PETStats3 = pd.read_excel( InFile2, sheet_name="PET_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxPET3 = S2PETStats3[StatsHdsList[100]].max()
S2MinPET3 = S2PETStats3[StatsHdsList[0]].min()
S2MaxPET3, S2MinPET3
# Out:
# (104.8058529360985, -103.6275386296342)

# %%
S2PETStats4 = pd.read_excel( InFile2, sheet_name="PET_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxPET4 = S2PETStats4[StatsHdsList[100]].max()
S2MinPET4 = S2PETStats4[StatsHdsList[0]].min()
S2MaxPET4, S2MinPET4
# Out:
# (120.786982515631, -106.661161662648)

# %%
S2MaxPET = max( S2MaxPET1, S2MaxPET2, S2MaxPET3, S2MaxPET4 )
S2MinPET = min( S2MinPET1, S2MinPET2, S2MinPET3, S2MinPET4 )
S2MaxPET, S2MinPET
# Out:
# (120.786982515631, -106.661161662648)

# %% [markdown]
# ### Scenario 3

# %%
InFile3 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT3 ) )
S3PETStats1 = pd.read_excel( InFile3, sheet_name="PET_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxPET1 = S3PETStats1[StatsHdsList[100]].max()
S3MinPET1 = S3PETStats1[StatsHdsList[0]].min()
S3MaxPET1, S3MinPET1
# Out:
# (0, 0)

# %%
S3PETStats2 = pd.read_excel( InFile3, sheet_name="PET_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxPET2 = S3PETStats2[StatsHdsList[100]].max()
S3MinPET2 = S3PETStats2[StatsHdsList[0]].min()
S3MaxPET2, S3MinPET2
# Out:
# (15.08591418949914, 0.6625203755926989)

# %%
S3PETStats3 = pd.read_excel( InFile3, sheet_name="PET_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxPET3 = S3PETStats3[StatsHdsList[100]].max()
S3MinPET3 = S3PETStats3[StatsHdsList[0]].min()
S3MaxPET3, S3MinPET3
# Out:
# (20.86583828035629, 2.095084570348146)

# %%
S3PETStats4 = pd.read_excel( InFile3, sheet_name="PET_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxPET4 = S3PETStats4[StatsHdsList[100]].max()
S3MinPET4 = S3PETStats4[StatsHdsList[0]].min()
S3MaxPET4, S3MinPET4
# Out:
# (29.39640398060089, 3.45656405941217)

# %%
S3MaxPET = max( S3MaxPET1, S3MaxPET2, S3MaxPET3, S3MaxPET4 )
S3MinPET = min( S3MinPET1, S3MinPET2, S3MinPET3, S3MinPET4 )
S3MaxPET, S3MinPET
# Out:
# (29.39640398060089, 0)

# %% [markdown]
# ## Plots

# %%
MaxPET = max( S1MaxPET, S2MaxPET, S3MaxPET )
MinPET = min( S1MinPET, S2MinPET, S3MinPET )
MaxPET, MinPET
# Out:
# (120.786982515631, -106.661161662648)

# %%
MaxPET = 200.0
MinPET = -200.0

# %% [markdown]
# Individual Plots

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S1MinPET, S1MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S1MinPET, S1MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S1MinPET, S1MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S1PETStats1.index, S1PETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S1PETStats2.index, S1PETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PETStats3.index, S1PETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PETStats4.index, S1PETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PETStats1.index, S1PETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S1PETStats2.index, S1PETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PETStats3.index, S1PETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PETStats4.index, S1PETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PETStats1.index, S1PETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S1PETStats2.index, S1PETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PETStats3.index, S1PETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PETStats4.index, S1PETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PETStats1.index, S1PETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S1PETStats2.index, S1PETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S1PETStats3.index, S1PETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S1PETStats4.index, S1PETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT1, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in PET (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S2MinPET, S2MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S2MinPET, S2MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S2MinPET, S2MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S2PETStats1.index, S2PETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S2PETStats2.index, S2PETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2PETStats3.index, S2PETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2PETStats4.index, S2PETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2PETStats1.index, S2PETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S2PETStats2.index, S2PETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2PETStats3.index, S2PETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2PETStats4.index, S2PETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2PETStats1.index, S2PETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S2PETStats2.index, S2PETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2PETStats3.index, S2PETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2PETStats4.index, S2PETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2PETStats1.index, S2PETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S2PETStats2.index, S2PETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S2PETStats3.index, S2PETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S2PETStats4.index, S2PETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT2, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in PET (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S3MinPET, S3MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S3MinPET, S3MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S3MinPET, S3MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S3PETStats1.index, S3PETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S3PETStats2.index, S3PETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3PETStats3.index, S3PETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3PETStats4.index, S3PETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3PETStats1.index, S3PETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S3PETStats2.index, S3PETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3PETStats3.index, S3PETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3PETStats4.index, S3PETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3PETStats1.index, S3PETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S3PETStats2.index, S3PETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3PETStats3.index, S3PETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3PETStats4.index, S3PETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3PETStats1.index, S3PETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S3PETStats2.index, S3PETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S3PETStats3.index, S3PETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S3PETStats4.index, S3PETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT3, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in PET (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %% [markdown]
# All together now

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_ScenPETDeltaPTH.svg" ) )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_ScenPETDeltaPTH.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_ScenPETDeltaPTH.png" ) )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_ScenPETDeltaPTH.png'

# %%
MaxPET = 150.0
MinPET = -150.0

# %%
petTicks = [ -150.0, -100.0, -50.0, -30.0, -10.0, 0.0, 10.0, 30.0, 50.0, 100.0, 150.0 ]

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(15, 21)
ax11 = Fig1.add_subplot(3,1,1)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinPET, MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinPET, MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinPET, MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S1PETStats1.index, S1PETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax11.plot( S1PETStats2.index, S1PETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PETStats3.index, S1PETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PETStats4.index, S1PETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1PETStats1.index, S1PETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S1PETStats2.index, S1PETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PETStats3.index, S1PETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PETStats4.index, S1PETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1PETStats1.index, S1PETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax11.plot( S1PETStats2.index, S1PETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PETStats3.index, S1PETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PETStats4.index, S1PETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1PETStats1.index, S1PETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax11.plot( S1PETStats2.index, S1PETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.plot( S1PETStats3.index, S1PETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.plot( S1PETStats4.index, S1PETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.set_yticks( petTicks )
ax11.set_ylim( (MinPET, MaxPET) )
ax11.grid(True, axis='y', which='both')
ax11.set_ylabel('Probabilistic Difference in PET (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower center', fontsize=11.0)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax11.annotate("A: Scenario 1", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax11.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21 = Fig1.add_subplot(3,1,2)
ax21.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinPET, MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinPET, MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinPET, MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( S2PETStats1.index, S2PETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax21.plot( S2PETStats2.index, S2PETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2PETStats3.index, S2PETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2PETStats4.index, S2PETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2PETStats1.index, S2PETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax21.plot( S2PETStats2.index, S2PETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2PETStats3.index, S2PETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2PETStats4.index, S2PETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2PETStats1.index, S2PETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax21.plot( S2PETStats2.index, S2PETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2PETStats3.index, S2PETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2PETStats4.index, S2PETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2PETStats1.index, S2PETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax21.plot( S2PETStats2.index, S2PETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.plot( S2PETStats3.index, S2PETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.plot( S2PETStats4.index, S2PETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax21.set_yticks( petTicks )
ax21.set_ylim( (MinPET, MaxPET) )
ax21.grid(True, axis='y', which='both')
ax21.set_ylabel('Probabilistic Difference in PET (mm)', fontsize=14)
ax21.grid( b=True )
ax21.legend( loc='lower center', fontsize=11.0)
ax21.tick_params(axis='both', which='major', labelsize=13)
ax21.tick_params(axis='x', which='major', labelrotation=30.0)
ax21.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax21.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax21.annotate("B: Scenario 2", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax21.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31 = Fig1.add_subplot(3,1,3)
ax31.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinPET, MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinPET, MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinPET, MaxPET], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( S3PETStats1.index, S3PETStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax31.plot( S3PETStats2.index, S3PETStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3PETStats3.index, S3PETStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3PETStats4.index, S3PETStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3PETStats1.index, S3PETStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax31.plot( S3PETStats2.index, S3PETStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3PETStats3.index, S3PETStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3PETStats4.index, S3PETStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3PETStats1.index, S3PETStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax31.plot( S3PETStats2.index, S3PETStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3PETStats3.index, S3PETStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3PETStats4.index, S3PETStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3PETStats1.index, S3PETStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax31.plot( S3PETStats2.index, S3PETStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.plot( S3PETStats3.index, S3PETStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.plot( S3PETStats4.index, S3PETStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax31.set_yticks( petTicks )
#ax31.set_ylim( (MinPET, MaxPET) )
ax31.set_ylim( (-50.0, 50.0) )
ax31.grid(True, axis='y', which='both')
ax31.set_ylabel('Probabilistic Difference in PET (mm)', fontsize=14)
ax31.grid( b=True )
ax31.legend( loc='lower center', fontsize=11.0)
ax31.tick_params(axis='both', which='major', labelsize=13)
ax31.tick_params(axis='x', which='major', labelrotation=30.0)
ax31.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax31.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax31.annotate("C: Scenario 3", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax31.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )
