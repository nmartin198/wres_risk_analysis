# %% [markdown]
# # Water Budget Results: Plot Delta Recharge (Re)

# %% [markdown]
# Plot recharge items from the water budget results

# %% [markdown]
# ## Parameters and Imports

# %%
# %matplotlib inline

# %%
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pickle
import seaborn as sns
from copy import deepcopy

# %%
IN_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Process_Results'
SIM_ROOT1 = "DC_WGMN1"
SIM_ROOT2 = "DC_WGMN2"
SIM_ROOT3 = "DC_WGMN3"
XLSX_ROOT = "%s_ProcessMonthly_Stats.xlsx"

# %%
OUT_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Events'

# %%
SM_NUM = 16

# %%
# time periods
TP_DICT = { 1 : [ dt.datetime(1981, 1, 1), dt.datetime(2010, 12, 31)],
            2 : [ dt.datetime(2011, 1, 1), dt.datetime(2040, 12, 31)],
            3 : [ dt.datetime(2041, 1, 1), dt.datetime(2070, 12, 31)],
            4 : [ dt.datetime(2071, 1, 1), dt.datetime(2100, 12, 31)],}

# %%
OurQs = np.array( [ round( 0.01 * x, 2 ) for x in range(101) ], dtype=np.float32 )
NumQs = len( OurQs )
NumQs
# Out:
# 101

# %%
StatsHdsList = list()
for iI in range(NumQs):
    cQ = OurQs[iI]
    Hdr = "%d_ptile" % round(cQ * 100.0)
    StatsHdsList.append( Hdr )
# end of for
StatsHdsList.append( "Average" )
StatsHdsList.append( "Variance" )
StatsHdsList.append( "Skew" )
StatsHdsList.append( "Kurt" )

# %%
NumHdrs = len( StatsHdsList )
NumHdrs
# Out:
# 105

# %%
RdHds = deepcopy( StatsHdsList )
RdHds.insert( 0, "Date" )

# %% [markdown]
# ## Load from Spreadsheets

# %% [markdown]
# ### Scenario 1

# %%
InFile1 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT1 ) )
S1REStats1 = pd.read_excel( InFile1, sheet_name="RE_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
display( HTML( S1REStats1.head().to_html() ) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0_ptile</th>
#       <th>1_ptile</th>
#       <th>2_ptile</th>
#       <th>3_ptile</th>
#       <th>4_ptile</th>
#       <th>5_ptile</th>
#       <th>6_ptile</th>
#       <th>7_ptile</th>
#       <th>8_ptile</th>
#       <th>9_ptile</th>
#       <th>10_ptile</th>
#       <th>11_ptile</th>
#       <th>12_ptile</th>
#       <th>13_ptile</th>
#       <th>14_ptile</th>
#       <th>15_ptile</th>
#       <th>16_ptile</th>
#       <th>17_ptile</th>
#       <th>18_ptile</th>
#       <th>19_ptile</th>
#       <th>20_ptile</th>
#       <th>21_ptile</th>
#       <th>22_ptile</th>
#       <th>23_ptile</th>
#       <th>24_ptile</th>
#       <th>25_ptile</th>
#       <th>26_ptile</th>
#       <th>27_ptile</th>
#       <th>28_ptile</th>
#       <th>29_ptile</th>
#       <th>30_ptile</th>
#       <th>31_ptile</th>
#       <th>32_ptile</th>
#       <th>33_ptile</th>
# ...

# %%
S1MaxRE1 = S1REStats1[StatsHdsList[100]].max()
S1MinRE1 = S1REStats1[StatsHdsList[0]].min()
S1MaxRE1, S1MinRE1
# Out:
# (0, 0)

# %%
S1REStats2 = pd.read_excel( InFile1, sheet_name="RE_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxRE2 = S1REStats2[StatsHdsList[100]].max()
S1MinRE2 = S1REStats2[StatsHdsList[0]].min()
S1MaxRE2, S1MinRE2
# Out:
# (32.68830866553608, -18.7776966959922)

# %%
S1REStats3 = pd.read_excel( InFile1, sheet_name="RE_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxRE3 = S1REStats3[StatsHdsList[100]].max()
S1MinRE3 = S1REStats3[StatsHdsList[0]].min()
S1MaxRE3, S1MinRE3
# Out:
# (34.315025281799, -17.67332869615891)

# %%
S1REStats4 = pd.read_excel( InFile1, sheet_name="RE_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxRE4 = S1REStats4[StatsHdsList[100]].max()
S1MinRE4 = S1REStats4[StatsHdsList[0]].min()
S1MaxRE4, S1MinRE4
# Out:
# (33.93955750666212, -18.04809983971782)

# %%
S1MaxRE = max( S1MaxRE1, S1MaxRE2, S1MaxRE3, S1MaxRE4 )
S1MinRE = min( S1MinRE1, S1MinRE2, S1MinRE3, S1MinRE4 )
S1MaxRE, S1MinRE
# Out:
# (34.315025281799, -18.7776966959922)

# %% [markdown]
# ### Scenario 2

# %%
InFile2 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT2 ) )
S2REStats1 = pd.read_excel( InFile2, sheet_name="RE_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxRE1 = S2REStats1[StatsHdsList[100]].max()
S2MinRE1 = S2REStats1[StatsHdsList[0]].min()
S2MaxRE1, S2MinRE1
# Out:
# (0, 0)

# %%
S2REStats2 = pd.read_excel( InFile2, sheet_name="RE_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxRE2 = S2REStats2[StatsHdsList[100]].max()
S2MinRE2 = S2REStats2[StatsHdsList[0]].min()
S2MaxRE2, S2MinRE2
# Out:
# (35.48482758675616, -18.39849785175668)

# %%
S2REStats3 = pd.read_excel( InFile2, sheet_name="RE_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxRE3 = S2REStats3[StatsHdsList[100]].max()
S2MinRE3 = S2REStats3[StatsHdsList[0]].min()
S2MaxRE3, S2MinRE3
# Out:
# (38.36646945703995, -17.14214403458755)

# %%
S2REStats4 = pd.read_excel( InFile2, sheet_name="RE_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxRE4 = S2REStats4[StatsHdsList[100]].max()
S2MinRE4 = S2REStats4[StatsHdsList[0]].min()
S2MaxRE4, S2MinRE4
# Out:
# (40.9503302772124, -17.47715860573702)

# %%
S2MaxRE = max( S2MaxRE1, S2MaxRE2, S2MaxRE3, S2MaxRE4 )
S2MinRE = min( S2MinRE1, S2MinRE2, S2MinRE3, S2MinRE4 )
S2MaxRE, S2MinRE
# Out:
# (40.9503302772124, -18.39849785175668)

# %% [markdown]
# ### Scenario 3

# %%
InFile3 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT3 ) )
S3REStats1 = pd.read_excel( InFile3, sheet_name="RE_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxRE1 = S3REStats1[StatsHdsList[100]].max()
S3MinRE1 = S3REStats1[StatsHdsList[0]].min()
S3MaxRE1, S3MinRE1
# Out:
# (0, 0)

# %%
S3REStats2 = pd.read_excel( InFile3, sheet_name="RE_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxRE2 = S3REStats2[StatsHdsList[100]].max()
S3MinRE2 = S3REStats2[StatsHdsList[0]].min()
S3MaxRE2, S3MinRE2
# Out:
# (5.510273351487854, -4.416367587421444)

# %%
S3REStats3 = pd.read_excel( InFile3, sheet_name="RE_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxRE3 = S3REStats3[StatsHdsList[100]].max()
S3MinRE3 = S3REStats3[StatsHdsList[0]].min()
S3MaxRE3, S3MinRE3
# Out:
# (5.191464095411757, -4.508054087449929)

# %%
S3REStats4 = pd.read_excel( InFile3, sheet_name="RE_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxRE4 = S3REStats4[StatsHdsList[100]].max()
S3MinRE4 = S3REStats4[StatsHdsList[0]].min()
S3MaxRE4, S3MinRE4
# Out:
# (7.159227793563538, -4.214827248169296)

# %%
S3MaxRE = max( S3MaxRE1, S3MaxRE2, S3MaxRE3, S3MaxRE4 )
S3MinRE = min( S3MinRE1, S3MinRE2, S3MinRE3, S3MinRE4 )
S3MaxRE, S3MinRE
# Out:
# (7.159227793563538, -4.508054087449929)

# %% [markdown]
# ## Plots

# %%
MaxRE = max( S1MaxRE, S2MaxRE, S3MaxRE )
MinRE = min( S1MinRE, S2MinRE, S3MinRE )
MaxRE, MinRE
# Out:
# (40.9503302772124, -18.7776966959922)

# %%
MaxRE = 50.0
MinRE = -50.0

# %% [markdown]
# Individual Plots

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S1MinRE, S1MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S1MinRE, S1MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S1MinRE, S1MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S1REStats1.index, S1REStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S1REStats2.index, S1REStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1REStats3.index, S1REStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1REStats4.index, S1REStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1REStats1.index, S1REStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S1REStats2.index, S1REStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1REStats3.index, S1REStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1REStats4.index, S1REStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1REStats1.index, S1REStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S1REStats2.index, S1REStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1REStats3.index, S1REStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1REStats4.index, S1REStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1REStats1.index, S1REStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S1REStats2.index, S1REStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S1REStats3.index, S1REStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S1REStats4.index, S1REStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT1, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in Recharge (RE) (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S2MinRE, S2MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S2MinRE, S2MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S2MinRE, S2MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S2REStats1.index, S2REStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S2REStats2.index, S2REStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2REStats3.index, S2REStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2REStats4.index, S2REStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2REStats1.index, S2REStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S2REStats2.index, S2REStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2REStats3.index, S2REStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2REStats4.index, S2REStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2REStats1.index, S2REStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S2REStats2.index, S2REStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2REStats3.index, S2REStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2REStats4.index, S2REStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2REStats1.index, S2REStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S2REStats2.index, S2REStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S2REStats3.index, S2REStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S2REStats4.index, S2REStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT2, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in Recharge (RE) (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S3MinRE, S3MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S3MinRE, S3MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S3MinRE, S3MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S3REStats1.index, S3REStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S3REStats2.index, S3REStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3REStats3.index, S3REStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3REStats4.index, S3REStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3REStats1.index, S3REStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S3REStats2.index, S3REStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3REStats3.index, S3REStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3REStats4.index, S3REStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3REStats1.index, S3REStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S3REStats2.index, S3REStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3REStats3.index, S3REStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3REStats4.index, S3REStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3REStats1.index, S3REStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S3REStats2.index, S3REStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S3REStats3.index, S3REStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S3REStats4.index, S3REStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT3, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in Recharge (RE) (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %% [markdown]
# All together now

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_ScenREDeltaPTH.svg" ) )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_ScenREDeltaPTH.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_ScenREDeltaPTH.png" ) )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_ScenREDeltaPTH.png'

# %%
MaxRE = 50.0
MinRE = -50.0

# %%
RETicks = [ -50.0, -30.0, -10.0, -5.0, 0.0, 5.0, 10.0, 30.0, 50.0 ]

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(15, 21)
ax11 = Fig1.add_subplot(3,1,1)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S1REStats1.index, S1REStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax11.plot( S1REStats2.index, S1REStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1REStats3.index, S1REStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1REStats4.index, S1REStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1REStats1.index, S1REStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S1REStats2.index, S1REStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1REStats3.index, S1REStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1REStats4.index, S1REStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1REStats1.index, S1REStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax11.plot( S1REStats2.index, S1REStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1REStats3.index, S1REStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1REStats4.index, S1REStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1REStats1.index, S1REStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax11.plot( S1REStats2.index, S1REStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.plot( S1REStats3.index, S1REStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.plot( S1REStats4.index, S1REStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.set_yticks( RETicks )
ax11.set_ylim( (MinRE, MaxRE) )
ax11.grid(True, axis='y', which='both')
ax11.set_ylabel('Probabilistic Difference in Recharge (Re) (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower center', fontsize=11.0)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax11.annotate("A: Scenario 1", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax11.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21 = Fig1.add_subplot(3,1,2)
ax21.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( S2REStats1.index, S2REStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax21.plot( S2REStats2.index, S2REStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2REStats3.index, S2REStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2REStats4.index, S2REStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2REStats1.index, S2REStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax21.plot( S2REStats2.index, S2REStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2REStats3.index, S2REStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2REStats4.index, S2REStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2REStats1.index, S2REStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax21.plot( S2REStats2.index, S2REStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2REStats3.index, S2REStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2REStats4.index, S2REStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2REStats1.index, S2REStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax21.plot( S2REStats2.index, S2REStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.plot( S2REStats3.index, S2REStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.plot( S2REStats4.index, S2REStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax21.set_yticks( RETicks )
ax21.set_ylim( (MinRE, MaxRE) )
ax21.grid(True, axis='y', which='both')
ax21.set_ylabel('Probabilistic Difference in Recharge (Re) (mm)', fontsize=14)
ax21.grid( b=True )
ax21.legend( loc='lower center', fontsize=11.0 )
ax21.tick_params(axis='both', which='major', labelsize=13)
ax21.tick_params(axis='x', which='major', labelrotation=30.0)
ax21.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax21.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax21.annotate("B: Scenario 2", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax21.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31 = Fig1.add_subplot(3,1,3)
ax31.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( S3REStats1.index, S3REStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax31.plot( S3REStats2.index, S3REStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3REStats3.index, S3REStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3REStats4.index, S3REStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3REStats1.index, S3REStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax31.plot( S3REStats2.index, S3REStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3REStats3.index, S3REStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3REStats4.index, S3REStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3REStats1.index, S3REStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax31.plot( S3REStats2.index, S3REStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3REStats3.index, S3REStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3REStats4.index, S3REStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3REStats1.index, S3REStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax31.plot( S3REStats2.index, S3REStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.plot( S3REStats3.index, S3REStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.plot( S3REStats4.index, S3REStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
#ax31.set_ylim( (MinRE, MaxRE) )
ax31.set_yticks( RETicks )
ax31.set_ylim( (-10.0, 10.0) )
ax31.grid(True, axis='y', which='both')
ax31.set_ylabel('Probabilistic Difference in Recharge (Re) (mm)', fontsize=14)
ax31.grid( b=True )
ax31.legend( loc='lower center', fontsize=11.0 )
ax31.tick_params(axis='both', which='major', labelsize=13)
ax31.tick_params(axis='x', which='major', labelrotation=30.0)
ax31.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax31.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax31.annotate("C: Scenario 3", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax31.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "FF_ReDelta_Sc2.svg" ) )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\FF_ReDelta_Sc2.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "FF_ReDelta_Sc2.png" ) )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\FF_ReDelta_Sc2.png'

# %%
RETicks = [ -10.0, -5.0, 0.0, 5.0, 10.0, 20.0 ]

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10, 6)
ax21 = Fig1.add_subplot(1,1,1)
ax21.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7 )
ax21.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7 )
ax21.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7 )
ax21.plot( S2REStats1.index, S2REStats1[StatsHdsList[95]], linestyle='dotted',
           linewidth=1, color='xkcd:gunmetal', label='95th percentile')
ax21.plot( S2REStats2.index, S2REStats2[StatsHdsList[95]], linestyle='dotted',
           linewidth=1, color='xkcd:gunmetal' )
ax21.plot( S2REStats3.index, S2REStats3[StatsHdsList[95]], linestyle='dotted',
           linewidth=1, color='xkcd:gunmetal' )
ax21.plot( S2REStats4.index, S2REStats4[StatsHdsList[95]], linestyle='dotted',
           linewidth=1, color='xkcd:gunmetal' )
ax21.plot( S2REStats1.index, S2REStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:medium grey', label='Mean' )
ax21.plot( S2REStats2.index, S2REStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:medium grey' )
ax21.plot( S2REStats3.index, S2REStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:medium grey' )
ax21.plot( S2REStats4.index, S2REStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:medium grey' )
ax21.plot( S2REStats1.index, S2REStats1[StatsHdsList[50]], linestyle='-',
           linewidth=1.5, color='xkcd:silver', label='Median, 50th percentile')
ax21.plot( S2REStats2.index, S2REStats2[StatsHdsList[50]], linestyle='-',
           linewidth=1.5, color='xkcd:silver' )
ax21.plot( S2REStats3.index, S2REStats3[StatsHdsList[50]], linestyle='-',
           linewidth=1.5, color='xkcd:silver' )
ax21.plot( S2REStats4.index, S2REStats4[StatsHdsList[50]], linestyle='-',
           linewidth=1.5, color='xkcd:silver' )
ax21.plot( S2REStats1.index, S2REStats1[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:battleship grey', label='5th percentile' )
ax21.plot( S2REStats2.index, S2REStats2[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:battleship grey' )
ax21.plot( S2REStats3.index, S2REStats3[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:battleship grey' )
ax21.plot( S2REStats4.index, S2REStats4[StatsHdsList[5]], linestyle='-',
           linewidth=1, color='xkcd:battleship grey' )
ax21.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax21.set_yticks( RETicks )
ax21.set_ylim( (-10.0, 20.0) )
ax21.grid(True, axis='y', which='both')
ax21.set_ylabel('Recharge $\Delta$ ($mm$)', fontsize=14)
ax21.grid( b=True )
ax21.legend( loc='lower center', ncol=2, fontsize=11.0 )
ax21.tick_params(axis='both', which='major', labelsize=13)
ax21.tick_params(axis='x', which='major', labelrotation=30.0)
ax21.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax21.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax21.annotate("Projection Interval 1", xy=(0.06, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 2", xy=(0.40, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 3", xy=(0.72, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )

# %% [markdown]
# Fourier smoothing

# %%
rft = np.fft.rfft( S2REStats1[StatsHdsList[95]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE1_95 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats2[StatsHdsList[95]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE2_95 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats3[StatsHdsList[95]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE3_95 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats4[StatsHdsList[95]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE4_95 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats1[StatsHdsList[5]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE1_5 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats2[StatsHdsList[5]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE2_5 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats3[StatsHdsList[5]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE3_5 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats4[StatsHdsList[5]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE4_5 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats1[StatsHdsList[50]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE1_50 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats2[StatsHdsList[50]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE2_50 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats3[StatsHdsList[50]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE3_50 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats4[StatsHdsList[50]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE4_50 = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats1[StatsHdsList[101]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE1_me = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats2[StatsHdsList[101]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE2_me = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats3[StatsHdsList[101]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE3_me = np.fft.irfft(rft)
rft = np.fft.rfft( S2REStats4[StatsHdsList[101]].to_numpy() )
rft[SM_NUM:] = 0.0
FF_RE4_me = np.fft.irfft(rft)

# %%
DTTL_2 = list( S2REStats2.index.to_pydatetime() )
DTTL_3 = list( S2REStats3.index.to_pydatetime() )
DTTL_4 = list( S2REStats4.index.to_pydatetime() )
BackDTList = deepcopy( DTTL_2 )
BackDTTL_2 = BackDTList[::-1]
BackDTList = deepcopy( DTTL_3 )
BackDTTL_3 = BackDTList[::-1]
BackDTList = deepcopy( DTTL_4 )
BackDTTL_4 = BackDTList[::-1]
DTTimeList = deepcopy( DTTL_2 )
DTTimeList.extend( DTTL_3 )
DTTimeList.extend( DTTL_4 )
DTTimeList.extend( BackDTTL_4 )
DTTimeList.extend( BackDTTL_3 )
DTTimeList.extend( BackDTTL_2 )

# %%
RE2_5 = list( FF_RE2_5 )
RE3_5 = list( FF_RE3_5 )
RE4_5 = list( FF_RE4_5 )
BackDTList = list( FF_RE4_95 )
BackRE4_95 = BackDTList[::-1]
BackDTList = list( FF_RE3_95 )
BackRE3_95 = BackDTList[::-1]
BackDTList = list( FF_RE2_95 )
BackRE2_95 = BackDTList[::-1]
REVals = deepcopy( RE2_5 )
REVals.extend( RE3_5 )
REVals.extend( RE4_5 )
REVals.extend( BackRE4_95 )
REVals.extend( BackRE3_95 )
REVals.extend( BackRE2_95 )

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "FF_REDelta_Sc2FSm.svg" ) )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\FF_REDelta_Sc2FSm.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "FF_REDelta_Sc2FSm.png" ) )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\FF_REDelta_Sc2FSm.png'

# %%
MaxRE = 200.0
MinRE = -125.0

# %%
RETicks = [ -100.0, -50.0, 0.0, 50.0, 100.0, 150.0 ]

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(12.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7)
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7 )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinRE, MaxRE], linestyle='-',
           linewidth=2, color='xkcd:black', alpha=0.7 )
sfF = ax11.fill( DTTimeList, REVals, color='xkcd:medium grey', alpha=0.40, 
                 label="5th to 95th percentile range")
ax11.plot( S2REStats2.index, FF_RE2_me, linestyle='-',
           linewidth=3, color='xkcd:gunmetal', label='Mean' )
ax11.plot( S2REStats3.index, FF_RE3_me, linestyle='-',
           linewidth=3, color='xkcd:gunmetal' )
ax11.plot( S2REStats4.index, FF_RE4_me, linestyle='-',
           linewidth=3, color='xkcd:gunmetal' )
ax11.plot( S2REStats2.index, FF_RE2_50, linestyle='dashed',
           linewidth=3, color='xkcd:pale grey', label='Median' )
ax11.plot( S2REStats3.index, FF_RE3_50, linestyle='dashed',
           linewidth=3, color='xkcd:pale grey' )
ax11.plot( S2REStats4.index, FF_RE4_50, linestyle='dashed',
           linewidth=3, color='xkcd:pale grey' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.set_yticks( RETicks )
ax11.set_ylim( (MinRE, MaxRE) )
ax11.grid(True, axis='y', which='both')
ax11.set_ylabel('Recharge $\Delta$ ($mm$)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower center', ncol=3, fontsize=12.0, facecolor="xkcd:light grey")
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=15.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax11.annotate("Projection Interval 1", xy=(0.09, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 2", xy=(0.42, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 3", xy=(0.75, 0.93), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:black", backgroundcolor="xkcd:light grey" )
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )
