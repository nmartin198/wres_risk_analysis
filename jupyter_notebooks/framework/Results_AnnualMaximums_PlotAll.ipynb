# %% [markdown]
# # Results: Annual Maximum, Daily Precipitation Depth

# %% [markdown]
# Compare the simulated maximum daily precipitation depth on an annual basis to the datasets

# %% [markdown]
# ## Imports and Parameters

# %%
# %matplotlib inline

# %%
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pickle
import seaborn as sns
from copy import deepcopy

# %%
IN_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Process_Results'
SIM_ROOT1 = "DC_WGMN1"
SIM_ROOT2 = "DC_WGMN2"
SIM_ROOT3 = "DC_WGMN3"

# %%
OUT_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Events'

# %% [markdown]
# ## Load

# %% [markdown]
# Load from previously saved

# %%
InFiler = os.path.normpath( os.path.join( OUT_DIR, "SimDF_%s_AnnMaxPre_All.pickle" % SIM_ROOT1 ) )
DPDF1 = pd.read_pickle( InFiler, compression='zip' )

# %%
InFiler = os.path.normpath( os.path.join( OUT_DIR, "SimDF_%s_AnnMaxPre_All.pickle" % SIM_ROOT2 ) )
DPDF2 = pd.read_pickle( InFiler, compression='zip' )

# %%
InFiler = os.path.normpath( os.path.join( OUT_DIR, "SimDF_%s_AnnMaxPre_All.pickle" % SIM_ROOT3 ) )
DPDF3 = pd.read_pickle( InFiler, compression='zip' )

# %% [markdown]
# ## Plots

# %%
sns.set(style="whitegrid", palette="pastel", color_codes=True)

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_AnnMax_All_BW.svg" ) )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_AnnMax_All_BW.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_AnnMax_All_BW.png" ) )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_AnnMax_All_BW.png'

# %%
preTicks = [ 10.0, 50.0, 100.0, 200.0, 300.0 ]

# %%
NOAA_24hr_2y = 76.0
NOAA_24hr_10y = 127.4
NOAA_24hr_25y = 167.3
NOAA_24hr_50y = 202.3
NOAA_24hr_100y = 242.7

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(15, 21)
ax11 = Fig1.add_subplot(3,1,1)
g1 = sns.boxplot( x="Interval", y="AnnMax", hue="DLabel",
                  dodge=True, linewidth=1.2, orient="v", showmeans=True,
                   palette={ "PRISM" : "xkcd:ocean blue", 
                             "LOCA" : "xkcd:sky blue",
                             "Simulated" : "xkcd:burnt orange", },
                   data=DPDF1, ax=ax11 )
xAxTup = g1.get_xlim( )
y100, = g1.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_100y, NOAA_24hr_100y ], linewidth=2.0,
                 linestyle='solid', color='xkcd:black', label="100-year, daily" )
y25, = g1.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_50y, NOAA_24hr_50y ], linewidth=2.0,
                linestyle='dashed', color='xkcd:steel', label="50-year, daily" )
y10, = g1.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_25y, NOAA_24hr_25y ], linewidth=2.0,
                linestyle='dotted', color='xkcd:steel', label="25-year, daily" )
y2, = g1.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_2y, NOAA_24hr_2y ], linewidth=2.0,
                linestyle='solid', color='xkcd:steel', label="2-year, daily" )
g1.legend(prop=dict(size=11))
g1.legend(loc="lower left")
g1.set_yscale('log')
g1.grid(b=True, which="both", axis='y')
g1.set_yticks( preTicks )
g1.set_xlabel('', fontsize=12 )
g1.set_ylabel('Annual Maximum Daily Precipitation Depth ($mm$)', fontsize=12)
g1.set_ylim( ( 5.0, 300.0 ))
g1.tick_params(axis='both', which='major', labelsize=11)
g1.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
g1.annotate("A: Scenario 1", xy=(0.90,0.93), xycoords="axes fraction")
ax21 = Fig1.add_subplot(3,1,2)
g2 = sns.boxplot( x="Interval", y="AnnMax", hue="DLabel",
                  dodge=True, linewidth=1.2, orient="v", showmeans=True,
                  palette={ "PRISM" : "xkcd:ocean blue", 
                             "LOCA" : "xkcd:sky blue",
                             "Simulated" : "xkcd:tangerine", },
                  data=DPDF2, ax=ax21 )
xAxTup = g2.get_xlim( )
y100, = g2.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_100y, NOAA_24hr_100y ], linewidth=2.0,
                 linestyle='solid', color='xkcd:black', label="100-year, daily" )
y25, = g2.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_50y, NOAA_24hr_50y ], linewidth=2.0,
                linestyle='dashed', color='xkcd:steel', label="50-year, daily" )
y10, = g2.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_25y, NOAA_24hr_25y ], linewidth=2.0,
                linestyle='dotted', color='xkcd:steel', label="25-year, daily" )
y2, = g2.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_2y, NOAA_24hr_2y ], linewidth=2.0,
                linestyle='solid', color='xkcd:steel', label="2-year, daily" )
g2.legend(prop=dict(size=11))
g2.legend(loc="lower left")
g2.set_yscale('log')
g2.grid(b=True, which="both", axis='y')
g2.set_yticks( preTicks )
g2.set_xlabel('', fontsize=12 )
g2.set_ylabel('Annual Maximum Daily Precipitation Depth ($mm$)', fontsize=12)
g2.set_ylim( ( 5.0, 300.0 ))
g2.tick_params(axis='both', which='major', labelsize=11)
g2.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
g2.annotate("B: Scenario 2", xy=(0.90,0.93), xycoords="axes fraction")
ax31 = Fig1.add_subplot(3,1,3)
g3 = sns.boxplot( x="Interval", y="AnnMax", hue="DLabel",
                  dodge=True, linewidth=1.2, orient="v", showmeans=True,
                  palette={ "PRISM" : "xkcd:ocean blue", 
                             "LOCA" : "xkcd:sky blue",
                             "Simulated" : "xkcd:pale orange", },
                  data=DPDF3, ax=ax31 )
xAxTup = g3.get_xlim( )
y100, = g3.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_100y, NOAA_24hr_100y ], linewidth=2.0,
                 linestyle='solid', color='xkcd:black', label="100-year, daily" )
y25, = g3.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_50y, NOAA_24hr_50y ], linewidth=2.0,
                linestyle='dashed', color='xkcd:steel', label="50-year, daily" )
y10, = g3.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_25y, NOAA_24hr_25y ], linewidth=2.0,
                linestyle='dotted', color='xkcd:steel', label="25-year, daily" )
y2, = g3.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_2y, NOAA_24hr_2y ], linewidth=2.0,
                linestyle='solid', color='xkcd:steel', label="2-year, daily" )
g3.legend(prop=dict(size=11))
g3.legend(loc="lower left")
g3.set_yscale('log')
g3.grid(b=True, which="both", axis='y')
g3.set_yticks( preTicks )
g3.set_xlabel('', fontsize=12 )
g3.set_ylabel('Annual Maximum Daily Precipitation Depth ($mm$)', fontsize=12)
g3.set_ylim( ( 5.0, 300.0 ))
g3.tick_params(axis='both', which='major', labelsize=11)
g3.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
g3.annotate("C: Scenario 3", xy=(0.90,0.93), xycoords="axes fraction")
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )

# %%
DPDF1["DLabel"].unique()
# Out:
# array(['PRISM', 'Simulated', 'LOCA'], dtype=object)

# %%
nDPDF1 = DPDF1.replace( to_replace="Simulated", value="Scenario 1" )
nDPDF1["DLabel"].unique()
# Out:
# array(['PRISM', 'Scenario 1', 'LOCA'], dtype=object)

# %%
nDPDF2 = DPDF2.replace( to_replace="Simulated", value="Scenario 2" )
nDPDF2 = nDPDF2[nDPDF2["DLabel"] == "Scenario 2" ].copy()

# %%
nDPDF3 = DPDF3.replace( to_replace="Simulated", value="Scenario 3" )
nDPDF3 = nDPDF3[nDPDF3["DLabel"] == "Scenario 3" ].copy()

# %%
All1 = pd.concat( [ nDPDF1, nDPDF2, nDPDF3 ], ignore_index=True )

# %%
All1["DLabel"].unique()
# Out:
# array(['PRISM', 'Scenario 1', 'LOCA', 'Scenario 2', 'Scenario 3'],
#       dtype=object)

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Fig_A6-AnnMax_Scenarios.svg") )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Fig_A6-AnnMax_Scenarios.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Fig_A6-AnnMax_Scenarios.png") )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Fig_A6-AnnMax_Scenarios.png'

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.5, 4.0)
ax11 = Fig1.add_subplot()
g1 = sns.boxplot( x="Interval", y="AnnMax", hue="DLabel",
                  dodge=True, linewidth=0.5, orient="v", showmeans=True,
                  palette={ "PRISM" : "xkcd:ocean blue", 
                              "LOCA" : "xkcd:sky blue",
                              "Scenario 1" : "xkcd:tangerine",
                              "Scenario 2" : "xkcd:pumpkin",
                              "Scenario 3" : "xkcd:burnt orange", },
                   data=All1, ax=ax11 )
xAxTup = g1.get_xlim( )
y100, = g1.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_100y, NOAA_24hr_100y ], linewidth=2.0,
                 linestyle='solid', color='xkcd:black', label="100-year, daily" )
y50, = g1.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_50y, NOAA_24hr_50y ], linewidth=2.0,
                linestyle='dashed', color='xkcd:steel', label="50-year, daily" )
y10, = g1.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_25y, NOAA_24hr_25y ], linewidth=2.0,
                linestyle='dotted', color='xkcd:steel', label="25-year, daily" )
y2, = g1.plot( [xAxTup[0], xAxTup[1]], [ NOAA_24hr_2y, NOAA_24hr_2y ], linewidth=2.0,
                linestyle='solid', color='xkcd:steel', label="2-year, daily" )
g1.legend(prop=dict(size=11))
g1.legend(loc="lower left", ncol=5)
g1.set_yscale('log')
g1.grid(b=True, which="both", axis='y')
g1.set_yticks( preTicks )
g1.set_xlabel('', fontsize=13 )
g1.set_ylabel('Annual Maximum, Daily Precipitation ($mm$)', fontsize=13)
g1.set_ylim( ( 3.0, 300.0 ))
g1.tick_params(axis='both', which='major', labelsize=12)
g1.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )
