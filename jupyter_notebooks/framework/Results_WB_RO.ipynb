# %% [markdown]
# # Water Budget Results: Plot Delta Runoff (RO)

# %% [markdown]
# Plot RO items from the water budget results

# %% [markdown]
# ## Parameters and Imports

# %%
# %matplotlib inline

# %%
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pickle
import seaborn as sns
from copy import deepcopy

# %%
IN_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Process_Results'
SIM_ROOT1 = "DC_WGMN1"
SIM_ROOT2 = "DC_WGMN2"
SIM_ROOT3 = "DC_WGMN3"
XLSX_ROOT = "%s_ProcessMonthly_Stats.xlsx"

# %%
OUT_DIR = r'C:\Users\nmartin\Documents\CC_IRD\Events'

# %%
# time periods
TP_DICT = { 1 : [ dt.datetime(1981, 1, 1), dt.datetime(2010, 12, 31)],
            2 : [ dt.datetime(2011, 1, 1), dt.datetime(2040, 12, 31)],
            3 : [ dt.datetime(2041, 1, 1), dt.datetime(2070, 12, 31)],
            4 : [ dt.datetime(2071, 1, 1), dt.datetime(2100, 12, 31)],}

# %%
OurQs = np.array( [ round( 0.01 * x, 2 ) for x in range(101) ], dtype=np.float32 )
NumQs = len( OurQs )
NumQs
# Out:
# 101

# %%
StatsHdsList = list()
for iI in range(NumQs):
    cQ = OurQs[iI]
    Hdr = "%d_ptile" % round(cQ * 100.0)
    StatsHdsList.append( Hdr )
# end of for
StatsHdsList.append( "Average" )
StatsHdsList.append( "Variance" )
StatsHdsList.append( "Skew" )
StatsHdsList.append( "Kurt" )

# %%
NumHdrs = len( StatsHdsList )
NumHdrs
# Out:
# 105

# %%
RdHds = deepcopy( StatsHdsList )
RdHds.insert( 0, "Date" )

# %% [markdown]
# ## Load from Spreadsheets

# %% [markdown]
# ### Scenario 1

# %%
InFile1 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT1 ) )
S1ROStats1 = pd.read_excel( InFile1, sheet_name="RO_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
display( HTML( S1ROStats1.head().to_html() ) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0_ptile</th>
#       <th>1_ptile</th>
#       <th>2_ptile</th>
#       <th>3_ptile</th>
#       <th>4_ptile</th>
#       <th>5_ptile</th>
#       <th>6_ptile</th>
#       <th>7_ptile</th>
#       <th>8_ptile</th>
#       <th>9_ptile</th>
#       <th>10_ptile</th>
#       <th>11_ptile</th>
#       <th>12_ptile</th>
#       <th>13_ptile</th>
#       <th>14_ptile</th>
#       <th>15_ptile</th>
#       <th>16_ptile</th>
#       <th>17_ptile</th>
#       <th>18_ptile</th>
#       <th>19_ptile</th>
#       <th>20_ptile</th>
#       <th>21_ptile</th>
#       <th>22_ptile</th>
#       <th>23_ptile</th>
#       <th>24_ptile</th>
#       <th>25_ptile</th>
#       <th>26_ptile</th>
#       <th>27_ptile</th>
#       <th>28_ptile</th>
#       <th>29_ptile</th>
#       <th>30_ptile</th>
#       <th>31_ptile</th>
#       <th>32_ptile</th>
#       <th>33_ptile</th>
# ...

# %%
S1MaxRO1 = S1ROStats1[StatsHdsList[100]].max()
S1MinRO1 = S1ROStats1[StatsHdsList[0]].min()
S1MaxRO1, S1MinRO1
# Out:
# (0, 0)

# %%
S1ROStats2 = pd.read_excel( InFile1, sheet_name="RO_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxRO2 = S1ROStats2[StatsHdsList[100]].max()
S1MinRO2 = S1ROStats2[StatsHdsList[0]].min()
S1MaxRO2, S1MinRO2
# Out:
# (22.05688843828345, -12.67051059108785)

# %%
S1ROStats3 = pd.read_excel( InFile1, sheet_name="RO_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxRO3 = S1ROStats3[StatsHdsList[100]].max()
S1MinRO3 = S1ROStats3[StatsHdsList[0]].min()
S1MaxRO3, S1MinRO3
# Out:
# (23.15453797692241, -11.92532300685487)

# %%
S1ROStats4 = pd.read_excel( InFile1, sheet_name="RO_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S1MaxRO4 = S1ROStats4[StatsHdsList[100]].max()
S1MinRO4 = S1ROStats4[StatsHdsList[0]].min()
S1MaxRO4, S1MinRO4
# Out:
# (22.90118590193126, -12.17820502005251)

# %%
S1MaxRO = max( S1MaxRO1, S1MaxRO2, S1MaxRO3, S1MaxRO4 )
S1MinRO = min( S1MinRO1, S1MinRO2, S1MinRO3, S1MinRO4 )
S1MaxRO, S1MinRO
# Out:
# (23.15453797692241, -12.67051059108785)

# %% [markdown]
# ### Scenario 2

# %%
InFile2 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT2 ) )
S2ROStats1 = pd.read_excel( InFile2, sheet_name="RO_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxRO1 = S2ROStats1[StatsHdsList[100]].max()
S2MinRO1 = S2ROStats1[StatsHdsList[0]].min()
S2MaxRO1, S2MinRO1
# Out:
# (0, 0)

# %%
S2ROStats2 = pd.read_excel( InFile2, sheet_name="RO_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxRO2 = S2ROStats2[StatsHdsList[100]].max()
S2MinRO2 = S2ROStats2[StatsHdsList[0]].min()
S2MaxRO2, S2MinRO2
# Out:
# (23.94387826366813, -12.4146409256118)

# %%
S2ROStats3 = pd.read_excel( InFile2, sheet_name="RO_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxRO3 = S2ROStats3[StatsHdsList[100]].max()
S2MinRO3 = S2ROStats3[StatsHdsList[0]].min()
S2MaxRO3, S2MinRO3
# Out:
# (25.88830597641022, -11.56689880876353)

# %%
S2ROStats4 = pd.read_excel( InFile2, sheet_name="RO_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S2MaxRO4 = S2ROStats4[StatsHdsList[100]].max()
S2MinRO4 = S2ROStats4[StatsHdsList[0]].min()
S2MaxRO4, S2MinRO4
# Out:
# (27.63180180648611, -11.79295452478881)

# %%
S2MaxRO = max( S2MaxRO1, S2MaxRO2, S2MaxRO3, S2MaxRO4 )
S2MinRO = min( S2MinRO1, S2MinRO2, S2MinRO3, S2MinRO4 )
S2MaxRO, S2MinRO
# Out:
# (27.63180180648611, -12.4146409256118)

# %% [markdown]
# ### Scenario 3

# %%
InFile3 = os.path.normpath( os.path.join( IN_DIR, XLSX_ROOT % SIM_ROOT3 ) )
S3ROStats1 = pd.read_excel( InFile3, sheet_name="RO_1", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxRO1 = S3ROStats1[StatsHdsList[100]].max()
S3MinRO1 = S3ROStats1[StatsHdsList[0]].min()
S3MaxRO1, S3MinRO1
# Out:
# (0, 0)

# %%
S3ROStats2 = pd.read_excel( InFile3, sheet_name="RO_2", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxRO2 = S3ROStats2[StatsHdsList[100]].max()
S3MinRO2 = S3ROStats2[StatsHdsList[0]].min()
S3MaxRO2, S3MinRO2
# Out:
# (3.718133165646326, -2.980005119717574)

# %%
S3ROStats3 = pd.read_excel( InFile3, sheet_name="RO_3", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxRO3 = S3ROStats3[StatsHdsList[100]].max()
S3MinRO3 = S3ROStats3[StatsHdsList[0]].min()
S3MaxRO3, S3MinRO3
# Out:
# (3.503012210129391, -3.041871853879844)

# %%
S3ROStats4 = pd.read_excel( InFile3, sheet_name="RO_4", header=0, names=RdHds, index_col=0,
                             parse_dates=True )

# %%
S3MaxRO4 = S3ROStats4[StatsHdsList[100]].max()
S3MinRO4 = S3ROStats4[StatsHdsList[0]].min()
S3MaxRO4, S3MinRO4
# Out:
# (4.830787984860686, -2.844012987968486)

# %%
S3MaxRO = max( S3MaxRO1, S3MaxRO2, S3MaxRO3, S3MaxRO4 )
S3MinRO = min( S3MinRO1, S3MinRO2, S3MinRO3, S3MinRO4 )
S3MaxRO, S3MinRO
# Out:
# (4.830787984860686, -3.041871853879844)

# %% [markdown]
# ## Plots

# %%
MaxRO = max( S1MaxRO, S2MaxRO, S3MaxRO )
MinRO = min( S1MinRO, S2MinRO, S3MinRO )
MaxRO, MinRO
# Out:
# (27.63180180648611, -12.67051059108785)

# %%
MaxRO = 40.0
MinRO = -40.0

# %% [markdown]
# Individual Plots

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S1MinRO, S1MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S1MinRO, S1MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S1MinRO, S1MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S1ROStats1.index, S1ROStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S1ROStats2.index, S1ROStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1ROStats3.index, S1ROStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1ROStats4.index, S1ROStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1ROStats1.index, S1ROStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S1ROStats2.index, S1ROStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1ROStats3.index, S1ROStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1ROStats4.index, S1ROStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1ROStats1.index, S1ROStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S1ROStats2.index, S1ROStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1ROStats3.index, S1ROStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1ROStats4.index, S1ROStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1ROStats1.index, S1ROStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S1ROStats2.index, S1ROStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S1ROStats3.index, S1ROStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S1ROStats4.index, S1ROStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT1, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in Runoff (RO) (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S2MinRO, S2MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S2MinRO, S2MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S2MinRO, S2MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S2ROStats1.index, S2ROStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S2ROStats2.index, S2ROStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2ROStats3.index, S2ROStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2ROStats4.index, S2ROStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S2ROStats1.index, S2ROStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S2ROStats2.index, S2ROStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2ROStats3.index, S2ROStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2ROStats4.index, S2ROStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S2ROStats1.index, S2ROStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S2ROStats2.index, S2ROStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2ROStats3.index, S2ROStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2ROStats4.index, S2ROStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S2ROStats1.index, S2ROStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S2ROStats2.index, S2ROStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S2ROStats3.index, S2ROStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S2ROStats4.index, S2ROStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT2, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in Runoff (RO) (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(10.0, 6.0)
ax11 = Fig1.add_subplot(111)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [S3MinRO, S3MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [S3MinRO, S3MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [S3MinRO, S3MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S3ROStats1.index, S3ROStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum')
ax11.plot( S3ROStats2.index, S3ROStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3ROStats3.index, S3ROStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3ROStats4.index, S3ROStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S3ROStats1.index, S3ROStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S3ROStats2.index, S3ROStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3ROStats3.index, S3ROStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3ROStats4.index, S3ROStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S3ROStats1.index, S3ROStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median')
ax11.plot( S3ROStats2.index, S3ROStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3ROStats3.index, S3ROStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3ROStats4.index, S3ROStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S3ROStats1.index, S3ROStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal', label='Minimum' )
ax11.plot( S3ROStats2.index, S3ROStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S3ROStats3.index, S3ROStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.plot( S3ROStats4.index, S3ROStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:teal' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.grid(True, axis='y', which='both')
ax11.set_title("Probabilistic Discharge %s" % SIM_ROOT3, fontsize=16)
ax11.set_ylabel('Probabilistic Difference in Runoff (RO) (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower left' )
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )

# %% [markdown]
# All together now

# %%
OutSVG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_ScenRODeltaPTH.svg" ) )
OutSVG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_ScenRODeltaPTH.svg'

# %%
OutPNG = os.path.normpath( os.path.join( OUT_DIR, "Plots", "Results_ScenRODeltaPTH.png" ) )
OutPNG
# Out:
# 'C:\\Users\\nmartin\\Documents\\CC_IRD\\Events\\Plots\\Results_ScenRODeltaPTH.png'

# %%
MaxRO = 30.0
MinRO = -30.0

# %%
ROTicks = [ -30.0, -20.0, -10.0, -5.0, 0.0, 5.0, 10.0, 20.0, 30.0 ]

# %%
Fig1 = plt.figure()
Fig1.set_size_inches(15, 21)
ax11 = Fig1.add_subplot(3,1,1)
ax11.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinRO, MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinRO, MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinRO, MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax11.plot( S1ROStats1.index, S1ROStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax11.plot( S1ROStats2.index, S1ROStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1ROStats3.index, S1ROStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1ROStats4.index, S1ROStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax11.plot( S1ROStats1.index, S1ROStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax11.plot( S1ROStats2.index, S1ROStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1ROStats3.index, S1ROStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1ROStats4.index, S1ROStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax11.plot( S1ROStats1.index, S1ROStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax11.plot( S1ROStats2.index, S1ROStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1ROStats3.index, S1ROStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1ROStats4.index, S1ROStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax11.plot( S1ROStats1.index, S1ROStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax11.plot( S1ROStats2.index, S1ROStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.plot( S1ROStats3.index, S1ROStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.plot( S1ROStats4.index, S1ROStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax11.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax11.set_yticks( ROTicks )
ax11.set_ylim( (MinRO, MaxRO) )
ax11.grid(True, axis='y', which='both')
ax11.set_ylabel('Probabilistic Difference in Runoff (RO) (mm)', fontsize=14)
ax11.grid( b=True )
ax11.legend( loc='lower center', fontsize=11.0)
ax11.tick_params(axis='both', which='major', labelsize=13)
ax11.tick_params(axis='x', which='major', labelrotation=30.0)
ax11.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax11.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax11.annotate("A: Scenario 1", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax11.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax11.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21 = Fig1.add_subplot(3,1,2)
ax21.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinRO, MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinRO, MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinRO, MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax21.plot( S2ROStats1.index, S2ROStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax21.plot( S2ROStats2.index, S2ROStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2ROStats3.index, S2ROStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2ROStats4.index, S2ROStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax21.plot( S2ROStats1.index, S2ROStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax21.plot( S2ROStats2.index, S2ROStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2ROStats3.index, S2ROStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2ROStats4.index, S2ROStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax21.plot( S2ROStats1.index, S2ROStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax21.plot( S2ROStats2.index, S2ROStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2ROStats3.index, S2ROStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2ROStats4.index, S2ROStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax21.plot( S2ROStats1.index, S2ROStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax21.plot( S2ROStats2.index, S2ROStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.plot( S2ROStats3.index, S2ROStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.plot( S2ROStats4.index, S2ROStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax21.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
ax21.set_yticks( ROTicks )
ax21.set_ylim( (MinRO, MaxRO) )
ax21.grid(True, axis='y', which='both')
ax21.set_ylabel('Probabilistic Difference in Runoff (RO) (mm)', fontsize=14)
ax21.grid( b=True )
ax21.legend( loc='lower center', fontsize=11.0 )
ax21.tick_params(axis='both', which='major', labelsize=13)
ax21.tick_params(axis='x', which='major', labelrotation=30.0)
ax21.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax21.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax21.annotate("B: Scenario 2", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax21.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax21.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31 = Fig1.add_subplot(3,1,3)
ax31.plot( [TP_DICT[2][0], TP_DICT[2][0]], [MinRO, MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( [TP_DICT[3][0], TP_DICT[3][0]], [MinRO, MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( [TP_DICT[4][0], TP_DICT[4][0]], [MinRO, MaxRO], linestyle='-',
           linewidth=2, color='xkcd:dark orange' )
ax31.plot( S3ROStats1.index, S3ROStats1[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy', label='Maximum, 100th percentile')
ax31.plot( S3ROStats2.index, S3ROStats2[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3ROStats3.index, S3ROStats3[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3ROStats4.index, S3ROStats4[StatsHdsList[100]], linestyle='-',
           linewidth=2, color='xkcd:navy' )
ax31.plot( S3ROStats1.index, S3ROStats1[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan', label='Mean' )
ax31.plot( S3ROStats2.index, S3ROStats2[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3ROStats3.index, S3ROStats3[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3ROStats4.index, S3ROStats4[StatsHdsList[101]], linestyle='-',
           linewidth=3, color='xkcd:cyan' )
ax31.plot( S3ROStats1.index, S3ROStats1[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue', label='Median, 50th percentile')
ax31.plot( S3ROStats2.index, S3ROStats2[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3ROStats3.index, S3ROStats3[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3ROStats4.index, S3ROStats4[StatsHdsList[50]], linestyle='-',
           linewidth=2, color='xkcd:bright blue' )
ax31.plot( S3ROStats1.index, S3ROStats1[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue', label='Minimum, 0th percentile' )
ax31.plot( S3ROStats2.index, S3ROStats2[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.plot( S3ROStats3.index, S3ROStats3[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.plot( S3ROStats4.index, S3ROStats4[StatsHdsList[0]], linestyle='-',
           linewidth=1, color='xkcd:steel blue' )
ax31.set_xlim( (dt.datetime(2010, 1, 1), TP_DICT[4][1]))
#ax31.set_ylim( (MinRO, MaxRO) )
ax31.set_yticks( ROTicks )
ax31.set_ylim( (-10.0, 10.0) )
ax31.grid(True, axis='y', which='both')
ax31.set_ylabel('Probabilistic Difference in Runoff (RO) (mm)', fontsize=14)
ax31.grid( b=True )
ax31.legend( loc='lower center', fontsize=11.0 )
ax31.tick_params(axis='both', which='major', labelsize=13)
ax31.tick_params(axis='x', which='major', labelrotation=30.0)
ax31.yaxis.set_major_formatter( mpl.ticker.StrMethodFormatter( "{x:,.1f}" ) )
ax31.xaxis.set_major_formatter( mpl.dates.DateFormatter("%Y-%m-%d") )
ax31.annotate("C: Scenario 3", xy=(0.88,0.06), xycoords="axes fraction", fontsize=12.0,
              backgroundcolor="xkcd:light grey")
ax31.annotate("Projection Interval 1", xy=(0.09, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31.annotate("Projection Interval 2", xy=(0.42, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
ax31.annotate("Projection Interval 3", xy=(0.75, 0.94), xycoords="axes fraction",
              fontsize=12.0, color="xkcd:dark orange", backgroundcolor="xkcd:light grey" )
Fig1.savefig( OutSVG )
Fig1.savefig( OutPNG )
